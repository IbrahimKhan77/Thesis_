# %% [markdown]
# <a href="https://colab.research.google.com/github/IbrahimKhan77/Thesis_/blob/main/Main_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn import metrics
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import mean_squared_error
from sklearn.metrics import precision_recall_fscore_support
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score 
import time


# !pip install category_encoders
import category_encoders as ce
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting category_encoders
#   Downloading category_encoders-2.5.1.post0-py2.py3-none-any.whl (72 kB)
#      |████████████████████████████████| 72 kB 615 kB/s
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.8/dist-packages (from category_encoders) (1.7.3)
# Requirement already satisfied: patsy>=0.5.1 in /usr/local/lib/python3.8/dist-packages (from category_encoders) (0.5.3)
# Requirement already satisfied: numpy>=1.14.0 in /usr/local/lib/python3.8/dist-packages (from category_encoders) (1.21.6)
# Requirement already satisfied: statsmodels>=0.9.0 in /usr/local/lib/python3.8/dist-packages (from category_encoders) (0.12.2)
# Requirement already satisfied: pandas>=1.0.5 in /usr/local/lib/python3.8/dist-packages (from category_encoders) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.8/dist-packages (from category_encoders) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.5->category_encoders) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.8/dist-packages (from pandas>=1.0.5->category_encoders) (2022.6)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from patsy>=0.5.1->category_encoders) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.0->category_encoders) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn>=0.20.0->category_encoders) (1.2.0)
# Installing collected packages: category-encoders
# Successfully installed category-encoders-2.5.1.post0

# %%
# !git clone https://github.com/IbrahimKhan77/Thesis_.git
# Out:
# Cloning into 'Thesis_'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (7/7), done.
# remote: Total 9 (delta 0), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), done.

# %%
df = pd.read_excel("/content/Thesis_/Survey-Data.xlsx")
df
# Out:
#      Gender Mode_of_study Year_of_study Home_wi-fi_access   \
# 0      Male     Full-time             3                Yes
# 1      Male     Full-time             3                Yes
# 2    Female     Full-time             3                Yes
# 3      Male     Full-time             3                Yes
# 4    Female     Full-time             3                Yes
# ..      ...           ...           ...                ...
# 420  Female     Full-time             3                Yes
# 421    Male     Full-time             1                Yes
# 422  Female     Full-time             3                Yes
# 423  Female     Full-time             1                Yes
# 424    Male     Full-time             1                Yes
#
#     home_desktop/laptop_access solely_for_your_use?  \
# 0                           No                  NaN
# 1                          Yes                  Yes
# 2                          Yes                  Yes
# 3                          Yes                  Yes
# 4                          Yes                  Yes
# ..                         ...                  ...
# 420                        Yes                  Yes
# 421                        Yes                  Yes
# 422                        Yes                  Yes
# 423                        Yes                   No
# 424                        Yes                   No
#
#      Self_Digital_knowlwedge_and_skills_rating         Question 1  \
# 0                                            6              Agree
# 1                                            8              Agree
# 2                                            4     Somewhat agree
# 3                                            6     Somewhat agree
# 4                                            8            Neutral
# ..                                         ...                ...
# 420                                          4  Somewhat disagree
# 421                                          7  Somewhat disagree
# 422                                          8     Somewhat agree
# 423                                          6              Agree
# 424                                          6     Somewhat agree
#
#             Question 2         Question 3  ...        Question 19  \
# 0                Agree              Agree  ...              Agree
# 1                Agree              Agree  ...              Agree
# 2    Somewhat disagree     Somewhat agree  ...            Neutral
# 3                Agree              Agree  ...     Somewhat agree
# 4    Strongly disagree  Strongly disagree  ...              Agree
# ..                 ...                ...  ...                ...
# 420  Somewhat disagree  Somewhat disagree  ...     Somewhat agree
# 421              Agree              Agree  ...            Neutral
# 422     Somewhat agree            Neutral  ...  Somewhat disagree
# 423              Agree              Agree  ...              Agree
# 424     Somewhat agree              Agree  ...     Somewhat agree
#
#            Question 20     Question 21        Question 22        Question 23  \
# 0                Agree           Agree              Agree              Agree
# 1                Agree  Strongly agree              Agree              Agree
# 2              Neutral        Disagree            Neutral            Neutral
# 3              Neutral  Somewhat agree              Agree              Agree
# 4                Agree  Strongly agree     Strongly agree     Strongly agree
# ..                 ...             ...                ...                ...
# 420  Somewhat disagree  Somewhat agree  Somewhat disagree              Agree
# 421  Somewhat disagree           Agree     Strongly agree  Strongly disagree
# 422            Neutral           Agree     Somewhat agree              Agree
# 423     Somewhat agree           Agree            Neutral           Disagree
# 424     Strongly agree  Somewhat agree     Somewhat agree     Somewhat agree
#
#         Question 24        Question 25        Question 26        Question 27  \
# 0             Agree              Agree              Agree              Agree
# 1           Neutral            Neutral            Neutral              Agree
# 2             Agree  Somewhat disagree              Agree  Somewhat disagree
# 3             Agree              Agree              Agree     Somewhat agree
# 4    Somewhat agree              Agree     Strongly agree     Somewhat agree
# ..              ...                ...                ...                ...
# 420           Agree     Somewhat agree            Neutral            Neutral
# 421         Neutral     Somewhat agree  Strongly disagree     Somewhat agree
# 422        Disagree     Somewhat agree  Strongly disagree  Somewhat disagree
# 423        Disagree            Neutral     Somewhat agree              Agree
# 424         Neutral     Somewhat agree            Neutral     Somewhat agree
#
#            Question 28
# 0                Agree
# 1                Agree
# 2    Somewhat disagree
# 3                Agree
# 4       Somewhat agree
# ..                 ...
# 420     Somewhat agree
# 421     Somewhat agree
# 422           Disagree
# 423              Agree
# 424     Somewhat agree
#
# [425 rows x 35 columns]

# %% [markdown]
# ### Ground Truth

# %%
# This is my groud truth, label, dependent variable
df['Question 28'].value_counts(normalize=True)
# Out:
# Neutral              0.235294
# Somewhat agree       0.200000
# Agree                0.190588
# Somewhat disagree    0.141176
# Strongly disagree    0.101176
# Disagree             0.084706
# Strongly agree       0.047059
# Name: Question 28, dtype: float64

# %%
df['Question 28'].value_counts(normalize=True).plot(kind="pie", shadow = True)
plt.legend()
plt.savefig("ground_truth_pie.png")

# %% [markdown]
# By above , we could say that 23% students are neautral and 43% agree, rest disagree
#
# ## **Univariate Data-viz**

# %%
df['Question 28'].value_counts().plot(kind="bar")

# %%
df['Question 27'].value_counts().plot(kind="bar")

# %%
df['Question 10'].value_counts().plot(kind="bar")

# %%
df['Year_of_study'].value_counts().plot(kind="bar")
plt.savefig("Year_of_study.png")

# %% [markdown]
# ### Replacing 'Others' with '1'

# %%
df['Year_of_study'] = df["Year_of_study"].replace('Others','1')
df["Year_of_study"].value_counts().plot(kind="bar")
plt.savefig("Year_of_study_.png")

# %%
df['Home_wi-fi_access '].value_counts().plot(kind="pie")
plt.savefig("Wifi-access.png")

# %%
df['home_desktop/laptop_access'].value_counts().plot(kind="bar")

# %%
df['Question 11'].value_counts().plot(kind="bar",figsize=(15, 8))
plt.savefig("dataViz_q11.png")

# %% [markdown]
# ## **Bi-variate Data-viz**

# %%
sns.set(rc = {'figure.figsize':(15,8)})
sns.histplot(x='Question 28' , y='Question 10' , data=df)

plt.savefig("histplot.png")

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15, 8))
sns.barplot(x=df['Question 28'], y=df['Self_Digital_knowlwedge_and_skills_rating'])
plt.xticks(rotation='40')

plt.savefig("barplot.png")

# %%
plt.figure(figsize=(15, 9))
sns.countplot(df['Question 28'],
              hue=df['Home_wi-fi_access '])
plt.xticks(rotation='40')

plt.savefig("bar.png", dpi=100)
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df['Gender'].value_counts(normalize=True)
# Out:
# Female    0.512941
# Male      0.487059
# Name: Gender, dtype: float64

# %%
df['Mode_of_study'].value_counts(normalize=True)
# Out:
# Full-time    0.971765
# Part-time    0.028235
# Name: Mode_of_study, dtype: float64

# %%
df['Year_of_study'].value_counts(normalize=True)
# Out:
# 3         0.411765
# 4         0.263529
# 2         0.174118
# 1         0.141176
# Others    0.009412
# Name: Year_of_study, dtype: float64

# %%
df['Gender'].value_counts(normalize=True).plot(kind="pie", shadow = True)
plt.legend(title = "Gender:")
plt.show() 
plt.savefig("gender_pie.png")

# %%
df['Mode_of_study'].value_counts(normalize=True).plot(kind="pie", shadow = True)
plt.legend(title = "Mode of study:")
plt.show() 
plt.savefig('studymode-pie.png')

# %%
df['Year_of_study'].value_counts(normalize=True).plot(kind="pie", shadow = True)
plt.legend(title = "Year of study:")
plt.show() 
plt.savefig("Year-pie.png")

# %% [markdown]
# ## We see that -
#
# 1.   Categorical columns with Questions needs to be converted to Numerical
# 2.   Only one column "solely_for_your_use?" is having missing values and rest all the columns have complete values, therefore missing values needs to be imputed
#
#
# **1 - Converting Categorical column into Numerical using Ordinal Encoding (Scikit learn)**

# %%
# Make a function of this

satisfaction_dict = {'Strongly agree': 1,'Agree': 2,'Somewhat agree': 3,'Neutral': 4,"Somewhat disagree":5, 'Disagree': 6,"Strongly disagree":7}
satisfaction_dict

df["Question_1"] = df['Question 1'].map(satisfaction_dict)
df["Question_2"] = df['Question 2'].map(satisfaction_dict)
df["Question_3"] = df['Question 3'].map(satisfaction_dict)
df["Question_4"] = df['Question 4'].map(satisfaction_dict)
df["Question_5"] = df['Question 5'].map(satisfaction_dict)
df["Question_6"] = df['Question 6'].map(satisfaction_dict)
df["Question_7"] = df['Question 7'].map(satisfaction_dict)
df["Question_8"] = df['Question 8'].map(satisfaction_dict)
df["Question_9"] = df['Question 9'].map(satisfaction_dict)
df["Question_10"] = df['Question 10'].map(satisfaction_dict)
df["Question_11"] = df['Question 11'].map(satisfaction_dict)
df["Question_12"] = df['Question 12'].map(satisfaction_dict)
df["Question_13"] = df['Question 13'].map(satisfaction_dict)
df["Question_14"] = df['Question 14'].map(satisfaction_dict)
df["Question_15"] = df['Question 15'].map(satisfaction_dict)
df["Question_16"] = df['Question 16'].map(satisfaction_dict)
df["Question_17"] = df['Question 17'].map(satisfaction_dict)
df["Question_18"] = df['Question 18'].map(satisfaction_dict)
df["Question_19"] = df['Question 19'].map(satisfaction_dict)
df["Question_20"] = df['Question 20'].map(satisfaction_dict)
df["Question_21"] = df['Question 21'].map(satisfaction_dict)
df["Question_22"] = df['Question 22'].map(satisfaction_dict)
df["Question_23"] = df['Question 23'].map(satisfaction_dict)
df["Question_24"] = df['Question 24'].map(satisfaction_dict)
df["Question_25"] = df['Question 25'].map(satisfaction_dict)
df["Question_26"] = df['Question 26'].map(satisfaction_dict)
df["Question_27"] = df['Question 27'].map(satisfaction_dict)


# Dependent variable
df["Question_28"] = df['Question 28'].map(satisfaction_dict)

# %% [markdown]
# **2 - Checking unique values in the column having missing values and imputing them with the Mode**

# %%
df['solely_for_your_use?'].value_counts(normalize=True)
# Out:
# Yes    0.803618
# No     0.196382
# Name: solely_for_your_use?, dtype: float64

# %%
most_frequent_category = df["solely_for_your_use?"].mode()[0]
    
df["solely_for_your_use?_Imp"] = df["solely_for_your_use?"]
df["solely_for_your_use?_Imp"].fillna(most_frequent_category, inplace=True)

df['solely_for_your_use?_Imp'].value_counts(normalize=True)
# Out:
# Yes    0.821176
# No     0.178824
# Name: solely_for_your_use?_Imp, dtype: float64

# %% [markdown]
# We see that there is very insignificant change in %(from 80% to 82% in "YES" and from 20% to 17.8% in "NO") after imputing misisng vaues with mode.

# %% [markdown]
# Now both the issues have been resolved

# %% [markdown]
# **Now converting the Categorical columns with Demographic details into numberical USING OneHot Encoder**

# %%
ce_OHE = ce.OneHotEncoder(cols=["Gender","Mode_of_study","Home_wi-fi_access ","home_desktop/laptop_access","solely_for_your_use?_Imp"])

data1 = ce_OHE.fit_transform(df)
data1.head()
# Out:
#    Gender_1  Gender_2  Mode_of_study_1  Mode_of_study_2 Year_of_study  \
# 0         1         0                1                0             3
# 1         1         0                1                0             3
# 2         0         1                1                0             3
# 3         1         0                1                0             3
# 4         0         1                1                0             3
#
#    Home_wi-fi_access _1  Home_wi-fi_access _2  home_desktop/laptop_access_1  \
# 0                     1                     0                             1
# 1                     1                     0                             0
# 2                     1                     0                             0
# 3                     1                     0                             0
# 4                     1                     0                             0
#
#    home_desktop/laptop_access_2 solely_for_your_use?  ...  Question_21  \
# 0                             0                  NaN  ...            2
# 1                             1                  Yes  ...            1
# 2                             1                  Yes  ...            6
# 3                             1                  Yes  ...            3
# 4                             1                  Yes  ...            1
#
#   Question_22 Question_23 Question_24 Question_25 Question_26 Question_27  \
# 0           2           2           2           2           2           2
# 1           2           2           4           4           4           2
# 2           4           4           2           5           2           5
# 3           2           2           2           2           2           3
# 4           1           1           3           2           1           3
#
#   Question_28 solely_for_your_use?_Imp_1 solely_for_your_use?_Imp_2
# 0           2                          1                          0
# 1           2                          1                          0
# 2           5                          1                          0
# 3           2                          1                          0
# 4           3                          1                          0
#
# [5 rows x 69 columns]

# %% [markdown]
# Chnage one hot end=coder to Get Dummies,
# Drop column "Device_use_for_learning"

# %% [markdown]
# **Dropping the un-necessary columns**

# %%
df2 = data1.drop(labels=['Question 1','solely_for_your_use?','Question 2','Question 3','Question 4','Question 5','Question 6','Question 7','Question 8',
                         'Question 9','Question 10','Question 11','Question 12','Question 13','Question 14','Question 15','Question 16','Question 17',
                         'Question 18','Question 19','Question 20','Question 21','Question 22','Question 23','Question 24','Question 25','Question 26',
                         'Question 27','Question 28'], axis=1)

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 425 entries, 0 to 424
# Data columns (total 40 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Gender_1                                   425 non-null    int64
#  1   Gender_2                                   425 non-null    int64
#  2   Mode_of_study_1                            425 non-null    int64
#  3   Mode_of_study_2                            425 non-null    int64
#  4   Year_of_study                              425 non-null    object
#  5   Home_wi-fi_access _1                       425 non-null    int64
#  6   Home_wi-fi_access _2                       425 non-null    int64
#  7   home_desktop/laptop_access_1               425 non-null    int64
#  8   home_desktop/laptop_access_2               425 non-null    int64
#  9   Self_Digital_knowlwedge_and_skills_rating  425 non-null    int64
#  10  Question_1                                 425 non-null    int64
#  11  Question_2                                 425 non-null    int64
#  12  Question_3                                 425 non-null    int64
#  13  Question_4                                 425 non-null    int64
#  14  Question_5                                 425 non-null    int64
#  15  Question_6                                 425 non-null    int64
#  16  Question_7                                 425 non-null    int64
#  17  Question_8                                 425 non-null    int64
#  18  Question_9                                 425 non-null    int64
#  19  Question_10                                425 non-null    int64
#  20  Question_11                                425 non-null    int64
#  21  Question_12                                425 non-null    int64
#  22  Question_13                                425 non-null    int64
#  23  Question_14                                425 non-null    int64
#  24  Question_15                                425 non-null    int64
#  25  Question_16                                425 non-null    int64
#  26  Question_17                                425 non-null    int64
#  27  Question_18                                425 non-null    int64
#  28  Question_19                                425 non-null    int64
#  29  Question_20                                425 non-null    int64
#  30  Question_21                                425 non-null    int64
#  31  Question_22                                425 non-null    int64
#  32  Question_23                                425 non-null    int64
#  33  Question_24                                425 non-null    int64
#  34  Question_25                                425 non-null    int64
#  35  Question_26                                425 non-null    int64
#  36  Question_27                                425 non-null    int64
#  37  Question_28                                425 non-null    int64
#  38  solely_for_your_use?_Imp_1                 425 non-null    int64
#  39  solely_for_your_use?_Imp_2                 425 non-null    int64
# dtypes: int64(39), object(1)
# memory usage: 132.9+ KB

# %%
import seaborn as sns
#sns.pairplot(df2)

# %%
import matplotlib.pyplot as plt

f = plt.figure(figsize=(19, 15))
plt.matshow(df2.corr(), fignum=f.number)

cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

plt.show()

# %% [markdown]
# ## Splitting the dataset into training and testing data
#
#
# We will split the data based on the year of study, since we want equal amount of students from all years to be in test data and train data as well.

# %%
#Checking the number of students in all the years from the whole dataset through bar graph

from pandas.core.arrays.interval import value_counts

df2["Year_of_study"].value_counts().plot(kind="bar")

# %%
#Converting all dtype to int64
df2["Year_of_study"] = pd.to_numeric(df2["Year_of_study"])

# %%
# Splitting the dataset using stratified splitter

from sklearn.model_selection import StratifiedShuffleSplit

st_splitter = StratifiedShuffleSplit(n_splits=1, test_size=0.2, random_state=7)

train_index, test_index = list(st_splitter.split(df2,df2["Year_of_study"]))[0]

train_set = df2.loc[train_index]
test_set = df2.loc[test_index]


# checking the proposition of students of different years in test data
test_set["Year_of_study"].value_counts().plot(kind="bar")

# %%
# checking the proposition of students of different years in Train data
train_set["Year_of_study"].value_counts().plot(kind="bar")

# %%
df3 = df2

# %% [markdown]
# **Alternate for stratififed splitting (use only one, either this or stratified)**

# %%
from sklearn.model_selection import train_test_split

train_set, test_set = train_test_split(df2,test_size=0.2, random_state=7)

test_set["Year_of_study"].value_counts().plot(kind="bar")

# %%
train_set["Year_of_study"].value_counts().plot(kind="bar")

# %% [markdown]
# ### From above bar graph we cound confirm that both the training and testing sets have almost equal proportion of students from all year of study
#
#
# # **Separating the Predictors/Independent Variables and the Target/Dependent variable From training and testing datasets**

# %%
Ytrain = train_set['Question_28'].copy()
Xtrain = train_set.drop("Question_28", axis=1)


Ytest = test_set['Question_28'].copy()
Xtest = test_set.drop('Question_28', axis=1)

# %%
print('Training dataset' , Xtrain.shape , Ytrain.shape)
print('Testing dataset' , Xtest.shape , Ytest.shape)
# Out:
# Training dataset (340, 39) (340,)
# Testing dataset (85, 39) (85,)

# %% [markdown]
# # **Setting up the baseline model**
#
# ### 1 - Dummy classifier

# %%
from sklearn.dummy import DummyClassifier

# Initialize Estimator
dummy_clf = DummyClassifier(strategy='stratified')

# Fitting the model
dummy_clf.fit(Xtrain,Ytrain)

# Evaluating model on test data
yhat_dummy_clas = dummy_clf.predict(Xtest)

# checking for Recall, Precision and Fscore of Baseline model
p,r,f,s = precision_recall_fscore_support(Ytest,yhat_dummy_clas, average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")
# Out:
# Precision:0.1869202226345083
# Recall: 0.21388414217361587
# F-score: 0.19748850891708036

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, yhat_dummy_clas)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig('CF_dummy.png')

# %% [markdown]
# ## Logistic regression

# %%
from sklearn import linear_model

log_reg = linear_model

# starting the timer
start = time.time()

log_reg = linear_model.LogisticRegression(max_iter=1900)
log_reg.fit(Xtrain,Ytrain)

end = time.time() - start
print(f"Logistic Regession took {end} seconds")

# Evaluating model on test data
yhat_log_Reg = log_reg.predict(Xtest)

# checking for Recall, Precision and Fscore of Baseline model
p,r,f,s = precision_recall_fscore_support(Ytest,yhat_log_Reg, average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, yhat_log_Reg, average='weighted')
# Out:
# Logistic Regession took 1.2115955352783203 seconds
# Precision:0.5012762680829908
# Recall: 0.5004748071477395
# F-score: 0.48993885371594353
# 0.4448837449201682

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, yhat_log_Reg)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CM_LR.PNG")

# %% [markdown]
# ## KNN

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=5)

# starting the timer
start = time.time()

knn.fit(Xtrain, Ytrain)

end = time.time() - start
print(f"KNN took {end} seconds")

# Evaluating model on test data
yhat_knn = knn.predict(Xtest)

# checking for Recall, Precision and Fscore of Baseline model
p,r,f,s = precision_recall_fscore_support(Ytest,yhat_knn, average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, yhat_knn, average='weighted')
# Out:
# KNN took 0.015282154083251953 seconds
# Precision:0.43576862595095417
# Recall: 0.3753271164925301
# F-score: 0.3739603533721181
# 0.3664111436429776

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, yhat_knn)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CM_LR.PNG")

# %% [markdown]
# ## Decision Tree

# %%
# import the regressor
from sklearn.tree import DecisionTreeClassifier 
  
# create a regressor object
d_tree = DecisionTreeClassifier(random_state = 0) 

# starting the timer
start = time.time()
  
# fit the regressor with X and Y data
d_tree.fit(Xtrain, Ytrain)

# predicting on the test set
y_pred = d_tree.predict(Xtest)

end = time.time() - start
print(f"Decision Tree took {end} seconds")

# checking for Recall, Precision and Fscore of Baseline model
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred, average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred, average='weighted')
# Out:
# Decision Tree took 0.011934280395507812 seconds
# Precision:0.5283344106873519
# Recall: 0.5960648374182209
# F-score: 0.5401291829863258
# 0.5429731488555019

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CM_DT.PNG")

# %% [markdown]
# ## Decision Tree with hyperparametre tuning

# %%
# Importing the GridSearchCV from sklearn API for hyperparameter tuning
from sklearn.model_selection import GridSearchCV

# Specifying the hyperparameters and setting
dt_params = [{'max_depth':[2,4,10,50,None]},
             {'random_state':[2,7,42]},
             {'max_features':[9,15,36]}]

# Instantiating the Grid search class (cross-validation)
grid_search = GridSearchCV(d_tree, dt_params, cv=10, scoring="f1_macro", return_train_score=True)

# Starting the timer
start = time.time()

# Fitting the model
grid_search.fit(Xtrain,Ytrain)

# predicting on the test set
y_pred_tuned = grid_search.predict(Xtest)

end = time.time() - start
print(f"Hyperparametre tuned Decision Tree took {end} seconds")

# checking for Recall, Precision and Fscore of Baseline model
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_tuned, average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred_tuned, average='weighted')
# Out:
# Hyperparametre tuned Decision Tree took 1.2347090244293213 seconds
# Precision:0.6595238095238096
# Recall: 0.6878775672948605
# F-score: 0.6587004177066288
# 0.6553518111574377

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_tuned)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CM_TUNED_DT.PNG")

# %% [markdown]
# ## Random forest

# %%
from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestClassifier


# create a RandomForestClassifier object
forest_reg = RandomForestClassifier(n_estimators= 10) 

# starting the timer
start = time.time()
  
# fit the regressor with X and Y data
forest_reg.fit(Xtrain, Ytrain)

# predicting on the test set
y_pred_RF = forest_reg.predict(Xtest)

end = time.time() - start
print(f"Random Forest took {end} seconds")

# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_RF,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

scores = cross_val_score(forest_reg, Xtrain, Ytrain, scoring = "neg_mean_squared_error" , cv=10)
rmse_scores = np.sqrt(-scores)

#print(rmse_scores)

metrics.f1_score(Ytest, y_pred_RF, average='weighted')
# Out:
# Random Forest took 0.0361025333404541 seconds
# Precision:0.6954466912623173
# Recall: 0.5996256875956124
# F-score: 0.6231650554958826
# 0.5958720330237358

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_RF)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CM_RF.PNG")

# %% [markdown]
# ### Random forest with hyperparameter tuning

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Initializing the RandomForestClassifier class
forest_reg_tuned = RandomForestClassifier(random_state=7)


# Specifiying the Parameters
param_grid = [{'n_estimators': [10,20,50,100],
               'max_depth': [1,2,5,10,15],
               'bootstrap': [True,False]},]

# Cross-validating for the Fscore for all Hyperparameters
rf_grid_search = GridSearchCV(forest_reg_tuned, param_grid , cv=10,
                              scoring='f1_macro',
                              return_train_score=True)

# starting the timer
start = time.time()


# Fitting the Random Forest HyperParameter Tuned model
rf_grid_search.fit(Xtrain, Ytrain)

end = time.time() - start
print(f"Hyperparametre Tuned Random forest took {end} seconds")

#finding the best MOdel
print(f"Best estimator  = {rf_grid_search.best_estimator_}")

# predicting on the test set
y_pred_RF_tuned = rf_grid_search.predict(Xtest)

# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_RF_tuned,average="micro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred_RF_tuned, average='weighted')
# Out:
# Hyperparametre Tuned Random forest took 35.76398253440857 seconds
# Best estimator  = RandomForestClassifier(bootstrap=False, max_depth=10, random_state=7)
# Precision:0.6470588235294118
# Recall: 0.6470588235294118
# F-score: 0.6470588235294118
# 0.6526903684550743

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_RF_tuned)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CM_TUNED_RF.PNG")

# %% [markdown]
# ## Support Vector Machine

# %%
from sklearn.svm import SVC
import warnings

# Instantiating the SVC class
svm_c = SVC()

# starting the timer
start = time.time()

# Fitting the Random Forest HyperParameter Tuned model
svm_c.fit(Xtrain, Ytrain)

end = time.time() - start
print(f"SVM took {end} seconds")


# predicting on the test set
y_pred_svm = svm_c.predict(Xtest)

# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_svm,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred_svm, average='weighted')
# Out:
# SVM took 0.03373908996582031 seconds
# Precision:0.3613550470693327
# Recall: 0.40473830680597594
# F-score: 0.37395719677511113
# /usr/local/lib/python3.8/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# 0.45950880456197457

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_svm)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_SVM.PNG")

# %% [markdown]
# ## Hyperparameter tuned Support vector machine

# %%
# Instantiating the SVC class
lsvm = SVC()

#Filtering out the warning for increasing number of Iterations as we already have set 'max_iter' = 8000
warnings.filterwarnings('ignore')

#specifying the Hyperparameters
param_grid_lsvm = {'C' : [0.01, 0.1, 1, 3, 10, 100],
                   'max_iter' : [10,50,100,1000,5000,10000],
                   'random_state' : [7,42]
                   }

# Cross-validating for the Fscore for all Hyperparameters
svm_grid_search = GridSearchCV(lsvm, param_grid_lsvm , cv=10,scoring='f1_macro',return_train_score=True)

# starting the timer
start = time.time()

# Fitting the Random Forest HyperParameter Tuned model
svm_grid_search.fit(Xtrain, Ytrain)

end = time.time() - start
print(f"SVM took {end} seconds")

#finding the best MOdel
print(f"Best estimator  = {svm_grid_search.best_estimator_}")

# predicting on the test set
y_pred_svm_tuned = svm_grid_search.predict(Xtest)

# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_svm_tuned,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred_svm_tuned, average='weighted')
# Out:
# SVM took 21.858311653137207 seconds
# Best estimator  = SVC(C=10, max_iter=100, random_state=7)
# Precision:0.4687558356676003
# Recall: 0.5308213716108453
# F-score: 0.4938106938106938
# 0.47826564532446886

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_svm_tuned)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_SVM_TUNED.PNG")

# %% [markdown]
# # **Neural networks**

# %%
# classification mlp model for the abalone dataset
from numpy import unique
from numpy import argmax
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import accuracy_score
from sklearn.preprocessing import LabelEncoder

n_class = len(unique(test_set))

# define the keras model
model = Sequential()
model.add(Dense(20, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(n_class, activation='softmax'))

# compile the keras model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')

# fit the keras model on the dataset
model.fit(Xtrain, Ytrain, epochs=200, batch_size=32, verbose=2)
# evaluate on test set
yhat_NN = model.predict(Xtest)
yhat_NN = argmax(yhat_NN, axis=-1).astype('int')
acc = accuracy_score(Ytest, yhat_NN)
print('Accuracy: %.3f' % acc)


# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,yhat_NN,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, yhat_NN, average='weighted')
# Out:
# Epoch 1/200
# 11/11 - 1s - loss: 7.9701 - 561ms/epoch - 51ms/step
# Epoch 2/200
# 11/11 - 0s - loss: 5.6303 - 29ms/epoch - 3ms/step
# Epoch 3/200
# 11/11 - 0s - loss: 4.1268 - 22ms/epoch - 2ms/step
# Epoch 4/200
# 11/11 - 0s - loss: 3.1976 - 25ms/epoch - 2ms/step
# Epoch 5/200
# 11/11 - 0s - loss: 2.7091 - 37ms/epoch - 3ms/step
# Epoch 6/200
# 11/11 - 0s - loss: 2.5063 - 26ms/epoch - 2ms/step
# Epoch 7/200
# 11/11 - 0s - loss: 2.3901 - 22ms/epoch - 2ms/step
# Epoch 8/200
# 11/11 - 0s - loss: 2.3100 - 24ms/epoch - 2ms/step
# Epoch 9/200
# 11/11 - 0s - loss: 2.2413 - 25ms/epoch - 2ms/step
# Epoch 10/200
# 11/11 - 0s - loss: 2.2023 - 22ms/epoch - 2ms/step
# Epoch 11/200
# 11/11 - 0s - loss: 2.1629 - 23ms/epoch - 2ms/step
# Epoch 12/200
# 11/11 - 0s - loss: 2.1315 - 22ms/epoch - 2ms/step
# Epoch 13/200
# 11/11 - 0s - loss: 2.1042 - 22ms/epoch - 2ms/step
# Epoch 14/200
# 11/11 - 0s - loss: 2.0779 - 23ms/epoch - 2ms/step
# Epoch 15/200
# 11/11 - 0s - loss: 2.0522 - 23ms/epoch - 2ms/step
# Epoch 16/200
# 11/11 - 0s - loss: 2.0248 - 30ms/epoch - 3ms/step
# Epoch 17/200
# 11/11 - 0s - loss: 2.0007 - 23ms/epoch - 2ms/step
# Epoch 18/200
# 11/11 - 0s - loss: 1.9763 - 30ms/epoch - 3ms/step
# Epoch 19/200
# 11/11 - 0s - loss: 1.9532 - 23ms/epoch - 2ms/step
# Epoch 20/200
# 11/11 - 0s - loss: 1.9294 - 22ms/epoch - 2ms/step
# Epoch 21/200
# 11/11 - 0s - loss: 1.9109 - 21ms/epoch - 2ms/step
# Epoch 22/200
# 11/11 - 0s - loss: 1.8854 - 23ms/epoch - 2ms/step
# Epoch 23/200
# 11/11 - 0s - loss: 1.8645 - 24ms/epoch - 2ms/step
# Epoch 24/200
# 11/11 - 0s - loss: 1.8443 - 36ms/epoch - 3ms/step
# Epoch 25/200
# 11/11 - 0s - loss: 1.8252 - 22ms/epoch - 2ms/step
# Epoch 26/200
# 11/11 - 0s - loss: 1.8070 - 24ms/epoch - 2ms/step
# Epoch 27/200
# 11/11 - 0s - loss: 1.7906 - 24ms/epoch - 2ms/step
# Epoch 28/200
# 11/11 - 0s - loss: 1.7731 - 25ms/epoch - 2ms/step
# Epoch 29/200
# 11/11 - 0s - loss: 1.7601 - 27ms/epoch - 2ms/step
# Epoch 30/200
# 11/11 - 0s - loss: 1.7439 - 26ms/epoch - 2ms/step
# Epoch 31/200
# 11/11 - 0s - loss: 1.7204 - 34ms/epoch - 3ms/step
# Epoch 32/200
# 11/11 - 0s - loss: 1.7040 - 25ms/epoch - 2ms/step
# Epoch 33/200
# 11/11 - 0s - loss: 1.6802 - 24ms/epoch - 2ms/step
# Epoch 34/200
# 11/11 - 0s - loss: 1.6624 - 27ms/epoch - 2ms/step
# Epoch 35/200
# 11/11 - 0s - loss: 1.6376 - 27ms/epoch - 2ms/step
# Epoch 36/200
# 11/11 - 0s - loss: 1.6132 - 22ms/epoch - 2ms/step
# Epoch 37/200
# 11/11 - 0s - loss: 1.5908 - 28ms/epoch - 3ms/step
# Epoch 38/200
# 11/11 - 0s - loss: 1.5647 - 38ms/epoch - 3ms/step
# Epoch 39/200
# 11/11 - 0s - loss: 1.5382 - 38ms/epoch - 3ms/step
# Epoch 40/200
# 11/11 - 0s - loss: 1.5215 - 27ms/epoch - 2ms/step
# Epoch 41/200
# 11/11 - 0s - loss: 1.4892 - 25ms/epoch - 2ms/step
# Epoch 42/200
# 11/11 - 0s - loss: 1.4748 - 23ms/epoch - 2ms/step
# Epoch 43/200
# 11/11 - 0s - loss: 1.4538 - 26ms/epoch - 2ms/step
# Epoch 44/200
# 11/11 - 0s - loss: 1.4341 - 22ms/epoch - 2ms/step
# Epoch 45/200
# 11/11 - 0s - loss: 1.4088 - 24ms/epoch - 2ms/step
# Epoch 46/200
# 11/11 - 0s - loss: 1.3969 - 29ms/epoch - 3ms/step
# Epoch 47/200
# 11/11 - 0s - loss: 1.3759 - 24ms/epoch - 2ms/step
# Epoch 48/200
# 11/11 - 0s - loss: 1.3624 - 24ms/epoch - 2ms/step
# Epoch 49/200
# 11/11 - 0s - loss: 1.3497 - 22ms/epoch - 2ms/step
# Epoch 50/200
# 11/11 - 0s - loss: 1.3305 - 22ms/epoch - 2ms/step
# Epoch 51/200
# 11/11 - 0s - loss: 1.3204 - 23ms/epoch - 2ms/step
# Epoch 52/200
# 11/11 - 0s - loss: 1.3031 - 24ms/epoch - 2ms/step
# Epoch 53/200
# 11/11 - 0s - loss: 1.2973 - 25ms/epoch - 2ms/step
# Epoch 54/200
# 11/11 - 0s - loss: 1.2946 - 27ms/epoch - 2ms/step
# Epoch 55/200
# 11/11 - 0s - loss: 1.2688 - 21ms/epoch - 2ms/step
# Epoch 56/200
# 11/11 - 0s - loss: 1.2599 - 23ms/epoch - 2ms/step
# Epoch 57/200
# 11/11 - 0s - loss: 1.2476 - 23ms/epoch - 2ms/step
# Epoch 58/200
# 11/11 - 0s - loss: 1.2443 - 22ms/epoch - 2ms/step
# Epoch 59/200
# 11/11 - 0s - loss: 1.2290 - 27ms/epoch - 2ms/step
# Epoch 60/200
# 11/11 - 0s - loss: 1.2240 - 22ms/epoch - 2ms/step
# Epoch 61/200
# 11/11 - 0s - loss: 1.2125 - 30ms/epoch - 3ms/step
# Epoch 62/200
# 11/11 - 0s - loss: 1.2036 - 25ms/epoch - 2ms/step
# Epoch 63/200
# 11/11 - 0s - loss: 1.1928 - 27ms/epoch - 2ms/step
# Epoch 64/200
# 11/11 - 0s - loss: 1.1864 - 24ms/epoch - 2ms/step
# Epoch 65/200
# 11/11 - 0s - loss: 1.1760 - 23ms/epoch - 2ms/step
# Epoch 66/200
# 11/11 - 0s - loss: 1.1728 - 25ms/epoch - 2ms/step
# Epoch 67/200
# 11/11 - 0s - loss: 1.1732 - 24ms/epoch - 2ms/step
# Epoch 68/200
# 11/11 - 0s - loss: 1.1566 - 23ms/epoch - 2ms/step
# Epoch 69/200
# 11/11 - 0s - loss: 1.1508 - 26ms/epoch - 2ms/step
# Epoch 70/200
# 11/11 - 0s - loss: 1.1424 - 26ms/epoch - 2ms/step
# Epoch 71/200
# 11/11 - 0s - loss: 1.1349 - 24ms/epoch - 2ms/step
# Epoch 72/200
# 11/11 - 0s - loss: 1.1277 - 22ms/epoch - 2ms/step
# Epoch 73/200
# 11/11 - 0s - loss: 1.1250 - 23ms/epoch - 2ms/step
# Epoch 74/200
# 11/11 - 0s - loss: 1.1147 - 37ms/epoch - 3ms/step
# Epoch 75/200
# 11/11 - 0s - loss: 1.1055 - 24ms/epoch - 2ms/step
# Epoch 76/200
# 11/11 - 0s - loss: 1.1050 - 24ms/epoch - 2ms/step
# Epoch 77/200
# 11/11 - 0s - loss: 1.0950 - 34ms/epoch - 3ms/step
# Epoch 78/200
# 11/11 - 0s - loss: 1.0896 - 23ms/epoch - 2ms/step
# Epoch 79/200
# 11/11 - 0s - loss: 1.0914 - 25ms/epoch - 2ms/step
# Epoch 80/200
# 11/11 - 0s - loss: 1.0778 - 24ms/epoch - 2ms/step
# Epoch 81/200
# 11/11 - 0s - loss: 1.0772 - 29ms/epoch - 3ms/step
# Epoch 82/200
# 11/11 - 0s - loss: 1.0823 - 23ms/epoch - 2ms/step
# Epoch 83/200
# 11/11 - 0s - loss: 1.0597 - 35ms/epoch - 3ms/step
# Epoch 84/200
# 11/11 - 0s - loss: 1.0582 - 22ms/epoch - 2ms/step
# Epoch 85/200
# 11/11 - 0s - loss: 1.0510 - 24ms/epoch - 2ms/step
# Epoch 86/200
# 11/11 - 0s - loss: 1.0437 - 31ms/epoch - 3ms/step
# Epoch 87/200
# 11/11 - 0s - loss: 1.0366 - 23ms/epoch - 2ms/step
# Epoch 88/200
# 11/11 - 0s - loss: 1.0389 - 25ms/epoch - 2ms/step
# Epoch 89/200
# 11/11 - 0s - loss: 1.0320 - 27ms/epoch - 2ms/step
# Epoch 90/200
# 11/11 - 0s - loss: 1.0246 - 24ms/epoch - 2ms/step
# Epoch 91/200
# 11/11 - 0s - loss: 1.0211 - 25ms/epoch - 2ms/step
# Epoch 92/200
# 11/11 - 0s - loss: 1.0164 - 25ms/epoch - 2ms/step
# Epoch 93/200
# 11/11 - 0s - loss: 1.0119 - 34ms/epoch - 3ms/step
# Epoch 94/200
# 11/11 - 0s - loss: 1.0068 - 25ms/epoch - 2ms/step
# Epoch 95/200
# 11/11 - 0s - loss: 1.0040 - 26ms/epoch - 2ms/step
# Epoch 96/200
# 11/11 - 0s - loss: 0.9984 - 27ms/epoch - 2ms/step
# Epoch 97/200
# 11/11 - 0s - loss: 0.9926 - 38ms/epoch - 3ms/step
# Epoch 98/200
# 11/11 - 0s - loss: 0.9921 - 25ms/epoch - 2ms/step
# Epoch 99/200
# 11/11 - 0s - loss: 0.9893 - 25ms/epoch - 2ms/step
# Epoch 100/200
# 11/11 - 0s - loss: 0.9826 - 29ms/epoch - 3ms/step
# Epoch 101/200
# 11/11 - 0s - loss: 0.9780 - 24ms/epoch - 2ms/step
# Epoch 102/200
# 11/11 - 0s - loss: 0.9722 - 23ms/epoch - 2ms/step
# Epoch 103/200
# 11/11 - 0s - loss: 0.9660 - 22ms/epoch - 2ms/step
# Epoch 104/200
# 11/11 - 0s - loss: 0.9640 - 24ms/epoch - 2ms/step
# Epoch 105/200
# 11/11 - 0s - loss: 0.9633 - 24ms/epoch - 2ms/step
# Epoch 106/200
# 11/11 - 0s - loss: 0.9534 - 22ms/epoch - 2ms/step
# Epoch 107/200
# 11/11 - 0s - loss: 0.9561 - 31ms/epoch - 3ms/step
# Epoch 108/200
# 11/11 - 0s - loss: 0.9520 - 34ms/epoch - 3ms/step
# Epoch 109/200
# 11/11 - 0s - loss: 0.9461 - 24ms/epoch - 2ms/step
# Epoch 110/200
# 11/11 - 0s - loss: 0.9445 - 24ms/epoch - 2ms/step
# Epoch 111/200
# 11/11 - 0s - loss: 0.9333 - 22ms/epoch - 2ms/step
# Epoch 112/200
# 11/11 - 0s - loss: 0.9308 - 27ms/epoch - 2ms/step
# Epoch 113/200
# 11/11 - 0s - loss: 0.9259 - 24ms/epoch - 2ms/step
# Epoch 114/200
# 11/11 - 0s - loss: 0.9279 - 38ms/epoch - 3ms/step
# Epoch 115/200
# 11/11 - 0s - loss: 0.9236 - 23ms/epoch - 2ms/step
# Epoch 116/200
# 11/11 - 0s - loss: 0.9223 - 24ms/epoch - 2ms/step
# Epoch 117/200
# 11/11 - 0s - loss: 0.9210 - 24ms/epoch - 2ms/step
# Epoch 118/200
# 11/11 - 0s - loss: 0.9035 - 30ms/epoch - 3ms/step
# Epoch 119/200
# 11/11 - 0s - loss: 0.9055 - 27ms/epoch - 2ms/step
# Epoch 120/200
# 11/11 - 0s - loss: 0.9099 - 24ms/epoch - 2ms/step
# Epoch 121/200
# 11/11 - 0s - loss: 0.9103 - 24ms/epoch - 2ms/step
# Epoch 122/200
# 11/11 - 0s - loss: 0.8983 - 28ms/epoch - 3ms/step
# Epoch 123/200
# 11/11 - 0s - loss: 0.8993 - 25ms/epoch - 2ms/step
# Epoch 124/200
# 11/11 - 0s - loss: 0.8878 - 24ms/epoch - 2ms/step
# Epoch 125/200
# 11/11 - 0s - loss: 0.8862 - 24ms/epoch - 2ms/step
# Epoch 126/200
# 11/11 - 0s - loss: 0.8772 - 24ms/epoch - 2ms/step
# Epoch 127/200
# 11/11 - 0s - loss: 0.8783 - 24ms/epoch - 2ms/step
# Epoch 128/200
# 11/11 - 0s - loss: 0.8738 - 23ms/epoch - 2ms/step
# Epoch 129/200
# 11/11 - 0s - loss: 0.8653 - 23ms/epoch - 2ms/step
# Epoch 130/200
# 11/11 - 0s - loss: 0.8690 - 38ms/epoch - 3ms/step
# Epoch 131/200
# 11/11 - 0s - loss: 0.8626 - 27ms/epoch - 2ms/step
# Epoch 132/200
# 11/11 - 0s - loss: 0.8601 - 24ms/epoch - 2ms/step
# Epoch 133/200
# 11/11 - 0s - loss: 0.8609 - 22ms/epoch - 2ms/step
# Epoch 134/200
# 11/11 - 0s - loss: 0.8543 - 24ms/epoch - 2ms/step
# Epoch 135/200
# 11/11 - 0s - loss: 0.8492 - 23ms/epoch - 2ms/step
# Epoch 136/200
# 11/11 - 0s - loss: 0.8562 - 23ms/epoch - 2ms/step
# Epoch 137/200
# 11/11 - 0s - loss: 0.8608 - 22ms/epoch - 2ms/step
# Epoch 138/200
# 11/11 - 0s - loss: 0.8424 - 32ms/epoch - 3ms/step
# Epoch 139/200
# 11/11 - 0s - loss: 0.8402 - 22ms/epoch - 2ms/step
# Epoch 140/200
# 11/11 - 0s - loss: 0.8368 - 26ms/epoch - 2ms/step
# Epoch 141/200
# 11/11 - 0s - loss: 0.8318 - 27ms/epoch - 2ms/step
# Epoch 142/200
# 11/11 - 0s - loss: 0.8254 - 29ms/epoch - 3ms/step
# Epoch 143/200
# 11/11 - 0s - loss: 0.8238 - 26ms/epoch - 2ms/step
# Epoch 144/200
# 11/11 - 0s - loss: 0.8239 - 24ms/epoch - 2ms/step
# Epoch 145/200
# 11/11 - 0s - loss: 0.8302 - 32ms/epoch - 3ms/step
# Epoch 146/200
# 11/11 - 0s - loss: 0.8147 - 28ms/epoch - 3ms/step
# Epoch 147/200
# 11/11 - 0s - loss: 0.8099 - 23ms/epoch - 2ms/step
# Epoch 148/200
# 11/11 - 0s - loss: 0.8148 - 24ms/epoch - 2ms/step
# Epoch 149/200
# 11/11 - 0s - loss: 0.8060 - 22ms/epoch - 2ms/step
# Epoch 150/200
# 11/11 - 0s - loss: 0.8047 - 25ms/epoch - 2ms/step
# Epoch 151/200
# 11/11 - 0s - loss: 0.8012 - 23ms/epoch - 2ms/step
# Epoch 152/200
# 11/11 - 0s - loss: 0.7959 - 24ms/epoch - 2ms/step
# Epoch 153/200
# 11/11 - 0s - loss: 0.7947 - 31ms/epoch - 3ms/step
# Epoch 154/200
# 11/11 - 0s - loss: 0.7905 - 23ms/epoch - 2ms/step
# Epoch 155/200
# 11/11 - 0s - loss: 0.7880 - 23ms/epoch - 2ms/step
# Epoch 156/200
# 11/11 - 0s - loss: 0.7903 - 24ms/epoch - 2ms/step
# Epoch 157/200
# 11/11 - 0s - loss: 0.7792 - 23ms/epoch - 2ms/step
# Epoch 158/200
# 11/11 - 0s - loss: 0.7796 - 27ms/epoch - 2ms/step
# Epoch 159/200
# 11/11 - 0s - loss: 0.7773 - 29ms/epoch - 3ms/step
# Epoch 160/200
# 11/11 - 0s - loss: 0.7780 - 23ms/epoch - 2ms/step
# Epoch 161/200
# 11/11 - 0s - loss: 0.7643 - 29ms/epoch - 3ms/step
# Epoch 162/200
# 11/11 - 0s - loss: 0.7729 - 28ms/epoch - 3ms/step
# Epoch 163/200
# 11/11 - 0s - loss: 0.7628 - 26ms/epoch - 2ms/step
# Epoch 164/200
# 11/11 - 0s - loss: 0.7584 - 36ms/epoch - 3ms/step
# Epoch 165/200
# 11/11 - 0s - loss: 0.7552 - 24ms/epoch - 2ms/step
# Epoch 166/200
# 11/11 - 0s - loss: 0.7524 - 23ms/epoch - 2ms/step
# Epoch 167/200
# 11/11 - 0s - loss: 0.7608 - 26ms/epoch - 2ms/step
# Epoch 168/200
# 11/11 - 0s - loss: 0.7528 - 28ms/epoch - 3ms/step
# Epoch 169/200
# 11/11 - 0s - loss: 0.7490 - 26ms/epoch - 2ms/step
# Epoch 170/200
# 11/11 - 0s - loss: 0.7563 - 27ms/epoch - 2ms/step
# Epoch 171/200
# 11/11 - 0s - loss: 0.7443 - 26ms/epoch - 2ms/step
# Epoch 172/200
# 11/11 - 0s - loss: 0.7390 - 22ms/epoch - 2ms/step
# Epoch 173/200
# 11/11 - 0s - loss: 0.7355 - 25ms/epoch - 2ms/step
# Epoch 174/200
# 11/11 - 0s - loss: 0.7300 - 23ms/epoch - 2ms/step
# Epoch 175/200
# 11/11 - 0s - loss: 0.7280 - 24ms/epoch - 2ms/step
# Epoch 176/200
# 11/11 - 0s - loss: 0.7279 - 32ms/epoch - 3ms/step
# Epoch 177/200
# 11/11 - 0s - loss: 0.7165 - 34ms/epoch - 3ms/step
# Epoch 178/200
# 11/11 - 0s - loss: 0.7176 - 23ms/epoch - 2ms/step
# Epoch 179/200
# 11/11 - 0s - loss: 0.7094 - 27ms/epoch - 2ms/step
# Epoch 180/200
# 11/11 - 0s - loss: 0.7112 - 27ms/epoch - 2ms/step
# Epoch 181/200
# 11/11 - 0s - loss: 0.7040 - 24ms/epoch - 2ms/step
# Epoch 182/200
# 11/11 - 0s - loss: 0.7102 - 25ms/epoch - 2ms/step
# Epoch 183/200
# 11/11 - 0s - loss: 0.7138 - 32ms/epoch - 3ms/step
# Epoch 184/200
# 11/11 - 0s - loss: 0.7048 - 25ms/epoch - 2ms/step
# Epoch 185/200
# 11/11 - 0s - loss: 0.7055 - 25ms/epoch - 2ms/step
# Epoch 186/200
# 11/11 - 0s - loss: 0.6992 - 24ms/epoch - 2ms/step
# Epoch 187/200
# 11/11 - 0s - loss: 0.6940 - 24ms/epoch - 2ms/step
# Epoch 188/200
# 11/11 - 0s - loss: 0.6896 - 21ms/epoch - 2ms/step
# Epoch 189/200
# 11/11 - 0s - loss: 0.6830 - 21ms/epoch - 2ms/step
# Epoch 190/200
# 11/11 - 0s - loss: 0.6868 - 24ms/epoch - 2ms/step
# Epoch 191/200
# 11/11 - 0s - loss: 0.6795 - 35ms/epoch - 3ms/step
# Epoch 192/200
# 11/11 - 0s - loss: 0.6780 - 24ms/epoch - 2ms/step
# Epoch 193/200
# 11/11 - 0s - loss: 0.6824 - 24ms/epoch - 2ms/step
# Epoch 194/200
# 11/11 - 0s - loss: 0.6743 - 30ms/epoch - 3ms/step
# Epoch 195/200
# 11/11 - 0s - loss: 0.6718 - 29ms/epoch - 3ms/step
# Epoch 196/200
# 11/11 - 0s - loss: 0.6640 - 26ms/epoch - 2ms/step
# Epoch 197/200
# 11/11 - 0s - loss: 0.6672 - 25ms/epoch - 2ms/step
# Epoch 198/200
# 11/11 - 0s - loss: 0.6615 - 33ms/epoch - 3ms/step
# Epoch 199/200
# 11/11 - 0s - loss: 0.6671 - 24ms/epoch - 2ms/step
# Epoch 200/200
# 11/11 - 0s - loss: 0.6617 - 25ms/epoch - 2ms/step
# 3/3 [==============================] - 0s 5ms/step
# Accuracy: 0.435
# Precision:0.4887254901960784
# Recall: 0.48324585815187326
# F-score: 0.48319227003437526
# 0.4332801831253843

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, yhat_NN)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_NN.PNG")

# %% [markdown]
# # Smote oversampling

# %%
Ytest.value_counts()
# Out:
# 4    19
# 2    16
# 3    15
# 5    14
# 7    11
# 6     8
# 1     2
# Name: Question_28, dtype: int64

# %%
from imblearn.over_sampling import SMOTE

# OverSampling by SMOTE the dataset
oversample = SMOTE(random_state=11)

#Fitting the SMOTE oversampling and storing the new train set in X_smote and Y_smote
X_smote, y_smote = oversample.fit_resample(Xtrain, Ytrain)

y_smote.value_counts()
# Out:
# 5    81
# 4    81
# 6    81
# 2    81
# 7    81
# 3    81
# 1    81
# Name: Question_28, dtype: int64

# %%
X_smote.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 567 entries, 0 to 566
# Data columns (total 39 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Gender_1                                   567 non-null    int64
#  1   Gender_2                                   567 non-null    int64
#  2   Mode_of_study_1                            567 non-null    int64
#  3   Mode_of_study_2                            567 non-null    int64
#  4   Year_of_study                              567 non-null    int64
#  5   Home_wi-fi_access _1                       567 non-null    int64
#  6   Home_wi-fi_access _2                       567 non-null    int64
#  7   home_desktop/laptop_access_1               567 non-null    int64
#  8   home_desktop/laptop_access_2               567 non-null    int64
#  9   Self_Digital_knowlwedge_and_skills_rating  567 non-null    int64
#  10  Question_1                                 567 non-null    int64
#  11  Question_2                                 567 non-null    int64
#  12  Question_3                                 567 non-null    int64
#  13  Question_4                                 567 non-null    int64
#  14  Question_5                                 567 non-null    int64
#  15  Question_6                                 567 non-null    int64
#  16  Question_7                                 567 non-null    int64
#  17  Question_8                                 567 non-null    int64
#  18  Question_9                                 567 non-null    int64
#  19  Question_10                                567 non-null    int64
#  20  Question_11                                567 non-null    int64
#  21  Question_12                                567 non-null    int64
#  22  Question_13                                567 non-null    int64
#  23  Question_14                                567 non-null    int64
#  24  Question_15                                567 non-null    int64
#  25  Question_16                                567 non-null    int64
#  26  Question_17                                567 non-null    int64
#  27  Question_18                                567 non-null    int64
#  28  Question_19                                567 non-null    int64
#  29  Question_20                                567 non-null    int64
#  30  Question_21                                567 non-null    int64
#  31  Question_22                                567 non-null    int64
#  32  Question_23                                567 non-null    int64
#  33  Question_24                                567 non-null    int64
#  34  Question_25                                567 non-null    int64
#  35  Question_26                                567 non-null    int64
#  36  Question_27                                567 non-null    int64
#  37  solely_for_your_use?_Imp_1                 567 non-null    int64
#  38  solely_for_your_use?_Imp_2                 567 non-null    int64
# dtypes: int64(39)
# memory usage: 172.9 KB

# %%
log_reg = linear_model

# starting the timer
start = time.time()

log_reg = linear_model.LogisticRegression(max_iter=1900)
log_reg.fit(X_smote,y_smote)

end = time.time() - start
print(f"Logistic Regession after smote oversampling took {end} seconds")

# Evaluating model on test data
yhat_log_Reg = log_reg.predict(Xtest)

# checking for Recall, Precision and Fscore of Baseline model
p,r,f,s = precision_recall_fscore_support(Ytest,yhat_log_Reg, average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, yhat_log_Reg, average='weighted')
# Out:
# Logistic Regession after smote oversampling took 1.2231035232543945 seconds
# Precision:0.49963450292397665
# Recall: 0.5039380106109429
# F-score: 0.49386189258312024
# 0.4498029186098992

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, yhat_log_Reg)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_LR_OS.PNG")

# %%
# create a CLASSIFIER object
d_tree = DecisionTreeClassifier(random_state = 0) 

# starting the timer
start = time.time()
  
# fit the regressor with X and Y data
d_tree.fit(X_smote, y_smote)

# predicting on the test set
y_pred = d_tree.predict(Xtest)

end = time.time() - start
print(f"Decision Tree after Smote Oversampling took {end} seconds")

# checking for Recall, Precision and Fscore of Baseline model
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred, average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred, average='weighted')
# Out:
# Decision Tree after Smote Oversampling took 0.014750480651855469 seconds
# Precision:0.6120809328516096
# Recall: 0.6536849428766722
# F-score: 0.6237658699843573
# 0.5798187510298237

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_DT_OS.PNG")

# %%
# Specifying the hyperparameters and setting
dt_params = [{'max_depth':[2,4,10,50,100,None]},
             {'random_state':[2,7,42]},
             {'max_features':[9,15,36]}]

# Instantiating the Grid search class (cross-validation)
grid_search = GridSearchCV(d_tree, dt_params, cv=10, scoring="f1_macro", return_train_score=True)

# Starting the timer
start = time.time()

# Fitting the model
grid_search.fit(X_smote, y_smote)

# predicting on the test set
y_pred_tuned = grid_search.predict(Xtest)

end = time.time() - start
print(f"Decision tree with hyperparametre tuning and smote oversampling took {end} seconds")

# checking for Recall, Precision and Fscore of Baseline model
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_tuned, average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred_tuned, average='weighted')
# Out:
# Decision tree with hyperparametre tuning and smote oversampling took 2.5250301361083984 seconds
# Precision:0.6007238792953079
# Recall: 0.6597939654330631
# F-score: 0.6230159051748256
# 0.5835052584995261

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_tuned)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_DT_TUNED_OS.PNG")

# %%
# create a RandomForestClassifier object
forest_reg = RandomForestClassifier(n_estimators= 10) 

# starting the timer
start = time.time()
  
# fit the regressor with X and Y data
forest_reg.fit(X_smote, y_smote)

# predicting on the test set
y_pred_RF = forest_reg.predict(Xtest)

end = time.time() - start
print(f"Random Forest WITH SMOTE OVERSAMPLING took {end} seconds")

# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_RF,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

scores = cross_val_score(forest_reg, Xtrain, Ytrain, scoring = "neg_mean_squared_error" , cv=10)
rmse_scores = np.sqrt(-scores)

#print(rmse_scores)

metrics.f1_score(Ytest, y_pred_RF, average='weighted')
# Out:
# Random Forest took 0.036310672760009766 seconds
# Precision:0.5939022881880024
# Recall: 0.6348798131692869
# F-score: 0.5856586270871986
# 0.5764395212630506

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_RF)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_RF_OS.PNG")

# %%
knn = KNeighborsClassifier(n_neighbors=5)

# starting the timer
start = time.time()

knn.fit(X_smote, y_smote)

end = time.time() - start
print(f"KNN WITH SMOTE OVERSAMPLING took {end} seconds")

# Evaluating model on test data
yhat_knn = knn.predict(Xtest)

# checking for Recall, Precision and Fscore of Baseline model
p,r,f,s = precision_recall_fscore_support(Ytest,yhat_knn, average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, yhat_knn, average='weighted')
# Out:
# KNN WITH SMOTE OVERSAMPLING took 0.0034942626953125 seconds
# Precision:0.43700525664811385
# Recall: 0.46101821111219604
# F-score: 0.4417186417186417
# 0.4676401288165995

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, yhat_knn)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_KNN_OS.PNG")

# %%
# Initializing the RandomForestClassifier class
forest_reg_tuned = RandomForestClassifier(random_state=7)

# Specifiying the Parameters
param_grid = [{'n_estimators': [10,20,50,100],
               'max_depth': [1,2,5,10,15],
               'bootstrap': [True,False]},]

# Cross-validating for the Fscore for all Hyperparameters
rf_grid_search = GridSearchCV(forest_reg_tuned, param_grid , cv=10,
                              scoring='f1_macro',
                              return_train_score=True)

# starting the timer
start = time.time()

# Fitting the Random Forest HyperParameter Tuned model
rf_grid_search.fit(X_smote, y_smote)

end = time.time() - start
print(f"Decision Tree took {end} seconds")

#finding the best MOdel
rf_grid_search.best_estimator_

# predicting on the test set
y_pred_RF_tuned = rf_grid_search.predict(Xtest)

# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_RF_tuned,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred_RF_tuned, average='weighted')
# Out:
# Decision Tree took 36.71357727050781 seconds
# Precision:0.6209490789322721
# Recall: 0.6423493799433649
# F-score: 0.6190284666371623
# 0.6047228342036527

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_RF_tuned)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_RF_TUNED_OS.PNG")

# %%
# Instantiating the SVC class
svm_c_ = SVC()

# starting the timer
start = time.time()

# Fitting the Random Forest HyperParameter Tuned model
svm_c_.fit(X_smote, y_smote)

end = time.time() - start
print(f"SVM after smote oversampling took {end} seconds")


# predicting on the test set
y_pred_svm = svm_c_.predict(Xtest)

# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_svm,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred_svm, average='weighted')
# Out:
# SVM after smote oversampling took 0.03013777732849121 seconds
# Precision:0.5160213220363596
# Recall: 0.5257685610129219
# F-score: 0.5150653579225007
# 0.538902578902579

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_svm)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_SVM_OS.PNG")

# %%
# Instantiating the SVC class
lsvm_OS = SVC()

#Filtering out the warning for increasing number of Iterations as we already have set 'max_iter' = 8000
warnings.filterwarnings('ignore')

#specifying the Hyperparameters
param_grid_lsvm = {'C' : [0.01, 0.1, 1, 3, 10, 100],
                   'max_iter' : [8000,10000],
                   'random_state' : [7]}

# Cross-validating for the Fscore for all Hyperparameters
svm_grid_search = GridSearchCV(lsvm_OS, param_grid_lsvm , cv=10,scoring='f1_macro',return_train_score=True)

# starting the timer
start = time.time()

# Fitting the Random Forest HyperParameter Tuned model
svm_grid_search.fit(X_smote, y_smote)

end = time.time() - start
print(f"SVM after smote oversampling AND HYPERPARAMETRE TUNING took {end} seconds")

#finding the best MOdel
print(f"Best estimator  = {svm_grid_search.best_estimator_}")

# predicting on the test set
y_pred_svm = svm_grid_search.predict(Xtest)

# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_svm,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred_svm, average='weighted')
# Out:
# SVM after smote oversampling AND HYPERPARAMETRE TUNING took 6.957857370376587 seconds
# Best estimator  = SVC(C=10, max_iter=8000, random_state=7)
# Precision:0.5079978479686188
# Recall: 0.5445350388959411
# F-score: 0.5149323525263375
# 0.49845773077971217

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_svm)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_SVM_TUNED_OS.PNG")

# %%
n_class = len(unique(test_set))

# define the keras model
model = Sequential()
model.add(Dense(20, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(n_class, activation='softmax'))

# compile the keras model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')

# fit the keras model on the dataset
model.fit(X_smote, y_smote, epochs=200, batch_size=32, verbose=2)
# evaluate on test set
yhat_NN = model.predict(Xtest)
yhat_NN = argmax(yhat_NN, axis=-1).astype('int')
acc = accuracy_score(Ytest, yhat_NN)
print('Accuracy: %.3f' % acc)

# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,yhat_NN,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, yhat_NN, average='weighted')
# Out:
# Epoch 1/200
# 18/18 - 0s - loss: 3.9312 - 475ms/epoch - 26ms/step
# Epoch 2/200
# 18/18 - 0s - loss: 2.6994 - 42ms/epoch - 2ms/step
# Epoch 3/200
# 18/18 - 0s - loss: 2.4267 - 40ms/epoch - 2ms/step
# Epoch 4/200
# 18/18 - 0s - loss: 2.3769 - 54ms/epoch - 3ms/step
# Epoch 5/200
# 18/18 - 0s - loss: 2.3470 - 40ms/epoch - 2ms/step
# Epoch 6/200
# 18/18 - 0s - loss: 2.3146 - 62ms/epoch - 3ms/step
# Epoch 7/200
# 18/18 - 0s - loss: 2.2584 - 43ms/epoch - 2ms/step
# Epoch 8/200
# 18/18 - 0s - loss: 2.1853 - 49ms/epoch - 3ms/step
# Epoch 9/200
# 18/18 - 0s - loss: 2.1063 - 35ms/epoch - 2ms/step
# Epoch 10/200
# 18/18 - 0s - loss: 2.0316 - 46ms/epoch - 3ms/step
# Epoch 11/200
# 18/18 - 0s - loss: 1.9597 - 41ms/epoch - 2ms/step
# Epoch 12/200
# 18/18 - 0s - loss: 1.9040 - 34ms/epoch - 2ms/step
# Epoch 13/200
# 18/18 - 0s - loss: 1.8502 - 42ms/epoch - 2ms/step
# Epoch 14/200
# 18/18 - 0s - loss: 1.8100 - 45ms/epoch - 3ms/step
# Epoch 15/200
# 18/18 - 0s - loss: 1.7714 - 51ms/epoch - 3ms/step
# Epoch 16/200
# 18/18 - 0s - loss: 1.7351 - 34ms/epoch - 2ms/step
# Epoch 17/200
# 18/18 - 0s - loss: 1.7014 - 35ms/epoch - 2ms/step
# Epoch 18/200
# 18/18 - 0s - loss: 1.6700 - 40ms/epoch - 2ms/step
# Epoch 19/200
# 18/18 - 0s - loss: 1.6395 - 36ms/epoch - 2ms/step
# Epoch 20/200
# 18/18 - 0s - loss: 1.6060 - 37ms/epoch - 2ms/step
# Epoch 21/200
# 18/18 - 0s - loss: 1.5651 - 36ms/epoch - 2ms/step
# Epoch 22/200
# 18/18 - 0s - loss: 1.5048 - 36ms/epoch - 2ms/step
# Epoch 23/200
# 18/18 - 0s - loss: 1.4372 - 34ms/epoch - 2ms/step
# Epoch 24/200
# 18/18 - 0s - loss: 1.3768 - 36ms/epoch - 2ms/step
# Epoch 25/200
# 18/18 - 0s - loss: 1.3390 - 35ms/epoch - 2ms/step
# Epoch 26/200
# 18/18 - 0s - loss: 1.2790 - 33ms/epoch - 2ms/step
# Epoch 27/200
# 18/18 - 0s - loss: 1.2430 - 41ms/epoch - 2ms/step
# Epoch 28/200
# 18/18 - 0s - loss: 1.2046 - 32ms/epoch - 2ms/step
# Epoch 29/200
# 18/18 - 0s - loss: 1.1669 - 34ms/epoch - 2ms/step
# Epoch 30/200
# 18/18 - 0s - loss: 1.1428 - 35ms/epoch - 2ms/step
# Epoch 31/200
# 18/18 - 0s - loss: 1.1191 - 33ms/epoch - 2ms/step
# Epoch 32/200
# 18/18 - 0s - loss: 1.0978 - 33ms/epoch - 2ms/step
# Epoch 33/200
# 18/18 - 0s - loss: 1.0786 - 39ms/epoch - 2ms/step
# Epoch 34/200
# 18/18 - 0s - loss: 1.0618 - 39ms/epoch - 2ms/step
# Epoch 35/200
# 18/18 - 0s - loss: 1.0475 - 46ms/epoch - 3ms/step
# Epoch 36/200
# 18/18 - 0s - loss: 1.0326 - 34ms/epoch - 2ms/step
# Epoch 37/200
# 18/18 - 0s - loss: 1.0178 - 39ms/epoch - 2ms/step
# Epoch 38/200
# 18/18 - 0s - loss: 0.9993 - 42ms/epoch - 2ms/step
# Epoch 39/200
# 18/18 - 0s - loss: 0.9891 - 33ms/epoch - 2ms/step
# Epoch 40/200
# 18/18 - 0s - loss: 0.9726 - 53ms/epoch - 3ms/step
# Epoch 41/200
# 18/18 - 0s - loss: 0.9604 - 35ms/epoch - 2ms/step
# Epoch 42/200
# 18/18 - 0s - loss: 0.9549 - 51ms/epoch - 3ms/step
# Epoch 43/200
# 18/18 - 0s - loss: 0.9421 - 36ms/epoch - 2ms/step
# Epoch 44/200
# 18/18 - 0s - loss: 0.9328 - 37ms/epoch - 2ms/step
# Epoch 45/200
# 18/18 - 0s - loss: 0.9197 - 39ms/epoch - 2ms/step
# Epoch 46/200
# 18/18 - 0s - loss: 0.9170 - 36ms/epoch - 2ms/step
# Epoch 47/200
# 18/18 - 0s - loss: 0.9063 - 33ms/epoch - 2ms/step
# Epoch 48/200
# 18/18 - 0s - loss: 0.8945 - 33ms/epoch - 2ms/step
# Epoch 49/200
# 18/18 - 0s - loss: 0.8885 - 32ms/epoch - 2ms/step
# Epoch 50/200
# 18/18 - 0s - loss: 0.8808 - 33ms/epoch - 2ms/step
# Epoch 51/200
# 18/18 - 0s - loss: 0.8663 - 36ms/epoch - 2ms/step
# Epoch 52/200
# 18/18 - 0s - loss: 0.8628 - 45ms/epoch - 2ms/step
# Epoch 53/200
# 18/18 - 0s - loss: 0.8555 - 37ms/epoch - 2ms/step
# Epoch 54/200
# 18/18 - 0s - loss: 0.8490 - 33ms/epoch - 2ms/step
# Epoch 55/200
# 18/18 - 0s - loss: 0.8449 - 31ms/epoch - 2ms/step
# Epoch 56/200
# 18/18 - 0s - loss: 0.8422 - 33ms/epoch - 2ms/step
# Epoch 57/200
# 18/18 - 0s - loss: 0.8326 - 34ms/epoch - 2ms/step
# Epoch 58/200
# 18/18 - 0s - loss: 0.8233 - 36ms/epoch - 2ms/step
# Epoch 59/200
# 18/18 - 0s - loss: 0.8205 - 40ms/epoch - 2ms/step
# Epoch 60/200
# 18/18 - 0s - loss: 0.8115 - 35ms/epoch - 2ms/step
# Epoch 61/200
# 18/18 - 0s - loss: 0.8060 - 33ms/epoch - 2ms/step
# Epoch 62/200
# 18/18 - 0s - loss: 0.8026 - 32ms/epoch - 2ms/step
# Epoch 63/200
# 18/18 - 0s - loss: 0.8039 - 41ms/epoch - 2ms/step
# Epoch 64/200
# 18/18 - 0s - loss: 0.7971 - 36ms/epoch - 2ms/step
# Epoch 65/200
# 18/18 - 0s - loss: 0.7862 - 48ms/epoch - 3ms/step
# Epoch 66/200
# 18/18 - 0s - loss: 0.7813 - 38ms/epoch - 2ms/step
# Epoch 67/200
# 18/18 - 0s - loss: 0.7817 - 44ms/epoch - 2ms/step
# Epoch 68/200
# 18/18 - 0s - loss: 0.7757 - 35ms/epoch - 2ms/step
# Epoch 69/200
# 18/18 - 0s - loss: 0.7655 - 34ms/epoch - 2ms/step
# Epoch 70/200
# 18/18 - 0s - loss: 0.7599 - 35ms/epoch - 2ms/step
# Epoch 71/200
# 18/18 - 0s - loss: 0.7546 - 34ms/epoch - 2ms/step
# Epoch 72/200
# 18/18 - 0s - loss: 0.7489 - 35ms/epoch - 2ms/step
# Epoch 73/200
# 18/18 - 0s - loss: 0.7448 - 32ms/epoch - 2ms/step
# Epoch 74/200
# 18/18 - 0s - loss: 0.7391 - 32ms/epoch - 2ms/step
# Epoch 75/200
# 18/18 - 0s - loss: 0.7297 - 39ms/epoch - 2ms/step
# Epoch 76/200
# 18/18 - 0s - loss: 0.7336 - 35ms/epoch - 2ms/step
# Epoch 77/200
# 18/18 - 0s - loss: 0.7239 - 29ms/epoch - 2ms/step
# Epoch 78/200
# 18/18 - 0s - loss: 0.7346 - 32ms/epoch - 2ms/step
# Epoch 79/200
# 18/18 - 0s - loss: 0.7129 - 34ms/epoch - 2ms/step
# Epoch 80/200
# 18/18 - 0s - loss: 0.7060 - 34ms/epoch - 2ms/step
# Epoch 81/200
# 18/18 - 0s - loss: 0.7081 - 33ms/epoch - 2ms/step
# Epoch 82/200
# 18/18 - 0s - loss: 0.7092 - 36ms/epoch - 2ms/step
# Epoch 83/200
# 18/18 - 0s - loss: 0.7002 - 47ms/epoch - 3ms/step
# Epoch 84/200
# 18/18 - 0s - loss: 0.6987 - 32ms/epoch - 2ms/step
# Epoch 85/200
# 18/18 - 0s - loss: 0.6885 - 34ms/epoch - 2ms/step
# Epoch 86/200
# 18/18 - 0s - loss: 0.6841 - 35ms/epoch - 2ms/step
# Epoch 87/200
# 18/18 - 0s - loss: 0.6818 - 36ms/epoch - 2ms/step
# Epoch 88/200
# 18/18 - 0s - loss: 0.6759 - 39ms/epoch - 2ms/step
# Epoch 89/200
# 18/18 - 0s - loss: 0.6727 - 38ms/epoch - 2ms/step
# Epoch 90/200
# 18/18 - 0s - loss: 0.6689 - 42ms/epoch - 2ms/step
# Epoch 91/200
# 18/18 - 0s - loss: 0.6651 - 51ms/epoch - 3ms/step
# Epoch 92/200
# 18/18 - 0s - loss: 0.6684 - 34ms/epoch - 2ms/step
# Epoch 93/200
# 18/18 - 0s - loss: 0.6594 - 35ms/epoch - 2ms/step
# Epoch 94/200
# 18/18 - 0s - loss: 0.6532 - 38ms/epoch - 2ms/step
# Epoch 95/200
# 18/18 - 0s - loss: 0.6555 - 34ms/epoch - 2ms/step
# Epoch 96/200
# 18/18 - 0s - loss: 0.6462 - 35ms/epoch - 2ms/step
# Epoch 97/200
# 18/18 - 0s - loss: 0.6451 - 37ms/epoch - 2ms/step
# Epoch 98/200
# 18/18 - 0s - loss: 0.6433 - 39ms/epoch - 2ms/step
# Epoch 99/200
# 18/18 - 0s - loss: 0.6403 - 33ms/epoch - 2ms/step
# Epoch 100/200
# 18/18 - 0s - loss: 0.6317 - 32ms/epoch - 2ms/step
# Epoch 101/200
# 18/18 - 0s - loss: 0.6374 - 34ms/epoch - 2ms/step
# Epoch 102/200
# 18/18 - 0s - loss: 0.6391 - 34ms/epoch - 2ms/step
# Epoch 103/200
# 18/18 - 0s - loss: 0.6350 - 37ms/epoch - 2ms/step
# Epoch 104/200
# 18/18 - 0s - loss: 0.6305 - 35ms/epoch - 2ms/step
# Epoch 105/200
# 18/18 - 0s - loss: 0.6230 - 29ms/epoch - 2ms/step
# Epoch 106/200
# 18/18 - 0s - loss: 0.6126 - 39ms/epoch - 2ms/step
# Epoch 107/200
# 18/18 - 0s - loss: 0.6132 - 35ms/epoch - 2ms/step
# Epoch 108/200
# 18/18 - 0s - loss: 0.6131 - 33ms/epoch - 2ms/step
# Epoch 109/200
# 18/18 - 0s - loss: 0.6054 - 31ms/epoch - 2ms/step
# Epoch 110/200
# 18/18 - 0s - loss: 0.6024 - 33ms/epoch - 2ms/step
# Epoch 111/200
# 18/18 - 0s - loss: 0.6038 - 32ms/epoch - 2ms/step
# Epoch 112/200
# 18/18 - 0s - loss: 0.6018 - 36ms/epoch - 2ms/step
# Epoch 113/200
# 18/18 - 0s - loss: 0.6021 - 35ms/epoch - 2ms/step
# Epoch 114/200
# 18/18 - 0s - loss: 0.5924 - 50ms/epoch - 3ms/step
# Epoch 115/200
# 18/18 - 0s - loss: 0.5893 - 37ms/epoch - 2ms/step
# Epoch 116/200
# 18/18 - 0s - loss: 0.5835 - 43ms/epoch - 2ms/step
# Epoch 117/200
# 18/18 - 0s - loss: 0.5866 - 37ms/epoch - 2ms/step
# Epoch 118/200
# 18/18 - 0s - loss: 0.5854 - 36ms/epoch - 2ms/step
# Epoch 119/200
# 18/18 - 0s - loss: 0.5818 - 34ms/epoch - 2ms/step
# Epoch 120/200
# 18/18 - 0s - loss: 0.5782 - 35ms/epoch - 2ms/step
# Epoch 121/200
# 18/18 - 0s - loss: 0.6006 - 35ms/epoch - 2ms/step
# Epoch 122/200
# 18/18 - 0s - loss: 0.5932 - 37ms/epoch - 2ms/step
# Epoch 123/200
# 18/18 - 0s - loss: 0.5721 - 31ms/epoch - 2ms/step
# Epoch 124/200
# 18/18 - 0s - loss: 0.5682 - 32ms/epoch - 2ms/step
# Epoch 125/200
# 18/18 - 0s - loss: 0.5750 - 33ms/epoch - 2ms/step
# Epoch 126/200
# 18/18 - 0s - loss: 0.5789 - 35ms/epoch - 2ms/step
# Epoch 127/200
# 18/18 - 0s - loss: 0.5765 - 31ms/epoch - 2ms/step
# Epoch 128/200
# 18/18 - 0s - loss: 0.5668 - 30ms/epoch - 2ms/step
# Epoch 129/200
# 18/18 - 0s - loss: 0.5613 - 37ms/epoch - 2ms/step
# Epoch 130/200
# 18/18 - 0s - loss: 0.5611 - 34ms/epoch - 2ms/step
# Epoch 131/200
# 18/18 - 0s - loss: 0.5521 - 34ms/epoch - 2ms/step
# Epoch 132/200
# 18/18 - 0s - loss: 0.5466 - 33ms/epoch - 2ms/step
# Epoch 133/200
# 18/18 - 0s - loss: 0.5517 - 36ms/epoch - 2ms/step
# Epoch 134/200
# 18/18 - 0s - loss: 0.5530 - 35ms/epoch - 2ms/step
# Epoch 135/200
# 18/18 - 0s - loss: 0.5446 - 44ms/epoch - 2ms/step
# Epoch 136/200
# 18/18 - 0s - loss: 0.5586 - 32ms/epoch - 2ms/step
# Epoch 137/200
# 18/18 - 0s - loss: 0.5534 - 39ms/epoch - 2ms/step
# Epoch 138/200
# 18/18 - 0s - loss: 0.5492 - 33ms/epoch - 2ms/step
# Epoch 139/200
# 18/18 - 0s - loss: 0.5306 - 38ms/epoch - 2ms/step
# Epoch 140/200
# 18/18 - 0s - loss: 0.5275 - 38ms/epoch - 2ms/step
# Epoch 141/200
# 18/18 - 0s - loss: 0.5293 - 34ms/epoch - 2ms/step
# Epoch 142/200
# 18/18 - 0s - loss: 0.5323 - 44ms/epoch - 2ms/step
# Epoch 143/200
# 18/18 - 0s - loss: 0.5256 - 44ms/epoch - 2ms/step
# Epoch 144/200
# 18/18 - 0s - loss: 0.5269 - 33ms/epoch - 2ms/step
# Epoch 145/200
# 18/18 - 0s - loss: 0.5268 - 35ms/epoch - 2ms/step
# Epoch 146/200
# 18/18 - 0s - loss: 0.5135 - 37ms/epoch - 2ms/step
# Epoch 147/200
# 18/18 - 0s - loss: 0.5127 - 34ms/epoch - 2ms/step
# Epoch 148/200
# 18/18 - 0s - loss: 0.5214 - 33ms/epoch - 2ms/step
# Epoch 149/200
# 18/18 - 0s - loss: 0.5199 - 34ms/epoch - 2ms/step
# Epoch 150/200
# 18/18 - 0s - loss: 0.5154 - 34ms/epoch - 2ms/step
# Epoch 151/200
# 18/18 - 0s - loss: 0.5011 - 34ms/epoch - 2ms/step
# Epoch 152/200
# 18/18 - 0s - loss: 0.5030 - 31ms/epoch - 2ms/step
# Epoch 153/200
# 18/18 - 0s - loss: 0.5061 - 34ms/epoch - 2ms/step
# Epoch 154/200
# 18/18 - 0s - loss: 0.5156 - 38ms/epoch - 2ms/step
# Epoch 155/200
# 18/18 - 0s - loss: 0.5066 - 35ms/epoch - 2ms/step
# Epoch 156/200
# 18/18 - 0s - loss: 0.4959 - 34ms/epoch - 2ms/step
# Epoch 157/200
# 18/18 - 0s - loss: 0.5037 - 37ms/epoch - 2ms/step
# Epoch 158/200
# 18/18 - 0s - loss: 0.4960 - 32ms/epoch - 2ms/step
# Epoch 159/200
# 18/18 - 0s - loss: 0.4892 - 34ms/epoch - 2ms/step
# Epoch 160/200
# 18/18 - 0s - loss: 0.4835 - 41ms/epoch - 2ms/step
# Epoch 161/200
# 18/18 - 0s - loss: 0.4872 - 33ms/epoch - 2ms/step
# Epoch 162/200
# 18/18 - 0s - loss: 0.4820 - 33ms/epoch - 2ms/step
# Epoch 163/200
# 18/18 - 0s - loss: 0.4791 - 37ms/epoch - 2ms/step
# Epoch 164/200
# 18/18 - 0s - loss: 0.4765 - 36ms/epoch - 2ms/step
# Epoch 165/200
# 18/18 - 0s - loss: 0.4829 - 42ms/epoch - 2ms/step
# Epoch 166/200
# 18/18 - 0s - loss: 0.4806 - 34ms/epoch - 2ms/step
# Epoch 167/200
# 18/18 - 0s - loss: 0.4745 - 34ms/epoch - 2ms/step
# Epoch 168/200
# 18/18 - 0s - loss: 0.4718 - 52ms/epoch - 3ms/step
# Epoch 169/200
# 18/18 - 0s - loss: 0.4732 - 34ms/epoch - 2ms/step
# Epoch 170/200
# 18/18 - 0s - loss: 0.4699 - 37ms/epoch - 2ms/step
# Epoch 171/200
# 18/18 - 0s - loss: 0.4714 - 34ms/epoch - 2ms/step
# Epoch 172/200
# 18/18 - 0s - loss: 0.4628 - 33ms/epoch - 2ms/step
# Epoch 173/200
# 18/18 - 0s - loss: 0.4665 - 54ms/epoch - 3ms/step
# Epoch 174/200
# 18/18 - 0s - loss: 0.4589 - 38ms/epoch - 2ms/step
# Epoch 175/200
# 18/18 - 0s - loss: 0.4553 - 33ms/epoch - 2ms/step
# Epoch 176/200
# 18/18 - 0s - loss: 0.4686 - 37ms/epoch - 2ms/step
# Epoch 177/200
# 18/18 - 0s - loss: 0.4665 - 34ms/epoch - 2ms/step
# Epoch 178/200
# 18/18 - 0s - loss: 0.4727 - 33ms/epoch - 2ms/step
# Epoch 179/200
# 18/18 - 0s - loss: 0.4610 - 41ms/epoch - 2ms/step
# Epoch 180/200
# 18/18 - 0s - loss: 0.4519 - 32ms/epoch - 2ms/step
# Epoch 181/200
# 18/18 - 0s - loss: 0.4524 - 34ms/epoch - 2ms/step
# Epoch 182/200
# 18/18 - 0s - loss: 0.4491 - 32ms/epoch - 2ms/step
# Epoch 183/200
# 18/18 - 0s - loss: 0.4526 - 34ms/epoch - 2ms/step
# Epoch 184/200
# 18/18 - 0s - loss: 0.4438 - 43ms/epoch - 2ms/step
# Epoch 185/200
# 18/18 - 0s - loss: 0.4520 - 38ms/epoch - 2ms/step
# Epoch 186/200
# 18/18 - 0s - loss: 0.4564 - 35ms/epoch - 2ms/step
# Epoch 187/200
# 18/18 - 0s - loss: 0.4433 - 38ms/epoch - 2ms/step
# Epoch 188/200
# 18/18 - 0s - loss: 0.4354 - 37ms/epoch - 2ms/step
# Epoch 189/200
# 18/18 - 0s - loss: 0.4373 - 36ms/epoch - 2ms/step
# Epoch 190/200
# 18/18 - 0s - loss: 0.4358 - 34ms/epoch - 2ms/step
# Epoch 191/200
# 18/18 - 0s - loss: 0.4479 - 35ms/epoch - 2ms/step
# Epoch 192/200
# 18/18 - 0s - loss: 0.4395 - 34ms/epoch - 2ms/step
# Epoch 193/200
# 18/18 - 0s - loss: 0.4322 - 47ms/epoch - 3ms/step
# Epoch 194/200
# 18/18 - 0s - loss: 0.4272 - 35ms/epoch - 2ms/step
# Epoch 195/200
# 18/18 - 0s - loss: 0.4284 - 34ms/epoch - 2ms/step
# Epoch 196/200
# 18/18 - 0s - loss: 0.4227 - 40ms/epoch - 2ms/step
# Epoch 197/200
# 18/18 - 0s - loss: 0.4251 - 36ms/epoch - 2ms/step
# Epoch 198/200
# 18/18 - 0s - loss: 0.4221 - 37ms/epoch - 2ms/step
# Epoch 199/200
# 18/18 - 0s - loss: 0.4267 - 36ms/epoch - 2ms/step
# Epoch 200/200
# 18/18 - 0s - loss: 0.4262 - 32ms/epoch - 2ms/step
# 3/3 [==============================] - 0s 6ms/step
# Accuracy: 0.471
# Precision:0.5367496280808973
# Recall: 0.4596922501057839
# F-score: 0.4698158523722434
# 0.4579512055177689

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, yhat_NN)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_NN_OS.PNG")

# %% [markdown]
# ## **Dropping the variables which are highly correlated from train and test sets for better data modelling**

# %%
# create correlation  matrix
corr_matrix = Xtrain.corr().abs()

# Select upper triangle of correlation matrix
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))

# Find features with correlation greater than 0.85
to_drop = [column for column in upper.columns if any(upper[column] > 0.75)]

# Drop features 
Xtrain.drop(to_drop, axis=1, inplace=True)
Xtest.drop(to_drop, axis=1, inplace=True)

Xtrain.info()
Xtest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 340 entries, 417 to 175
# Data columns (total 33 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Gender_1                                   340 non-null    int64
#  1   Mode_of_study_1                            340 non-null    int64
#  2   Year_of_study                              340 non-null    int64
#  3   Home_wi-fi_access _1                       340 non-null    int64
#  4   home_desktop/laptop_access_1               340 non-null    int64
#  5   Self_Digital_knowlwedge_and_skills_rating  340 non-null    int64
#  6   Question_1                                 340 non-null    int64
#  7   Question_2                                 340 non-null    int64
#  8   Question_3                                 340 non-null    int64
#  9   Question_4                                 340 non-null    int64
#  10  Question_5                                 340 non-null    int64
#  11  Question_6                                 340 non-null    int64
#  12  Question_7                                 340 non-null    int64
#  13  Question_8                                 340 non-null    int64
#  14  Question_9                                 340 non-null    int64
#  15  Question_10                                340 non-null    int64
#  16  Question_11                                340 non-null    int64
#  17  Question_12                                340 non-null    int64
#  18  Question_13                                340 non-null    int64
#  19  Question_14                                340 non-null    int64
#  20  Question_15                                340 non-null    int64
#  21  Question_16                                340 non-null    int64
#  22  Question_17                                340 non-null    int64
#  23  Question_19                                340 non-null    int64
#  24  Question_20                                340 non-null    int64
#  25  Question_21                                340 non-null    int64
#  26  Question_22                                340 non-null    int64
#  27  Question_23                                340 non-null    int64
#  28  Question_24                                340 non-null    int64
#  29  Question_25                                340 non-null    int64
#  30  Question_26                                340 non-null    int64
#  31  Question_27                                340 non-null    int64
#  32  solely_for_your_use?_Imp_1                 340 non-null    int64
# dtypes: int64(33)
# memory usage: 90.3 KB
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 85 entries, 51 to 159
# Data columns (total 33 columns):
#  #   Column                                     Non-Null Count  Dtype
# ---  ------                                     --------------  -----
#  0   Gender_1                                   85 non-null     int64
#  1   Mode_of_study_1                            85 non-null     int64
#  2   Year_of_study                              85 non-null     int64
#  3   Home_wi-fi_access _1                       85 non-null     int64
#  4   home_desktop/laptop_access_1               85 non-null     int64
#  5   Self_Digital_knowlwedge_and_skills_rating  85 non-null     int64
#  6   Question_1                                 85 non-null     int64
#  7   Question_2                                 85 non-null     int64
#  8   Question_3                                 85 non-null     int64
#  9   Question_4                                 85 non-null     int64
#  10  Question_5                                 85 non-null     int64
#  11  Question_6                                 85 non-null     int64
#  12  Question_7                                 85 non-null     int64
#  13  Question_8                                 85 non-null     int64
#  14  Question_9                                 85 non-null     int64
#  15  Question_10                                85 non-null     int64
#  16  Question_11                                85 non-null     int64
#  17  Question_12                                85 non-null     int64
#  18  Question_13                                85 non-null     int64
#  19  Question_14                                85 non-null     int64
#  20  Question_15                                85 non-null     int64
#  21  Question_16                                85 non-null     int64
#  22  Question_17                                85 non-null     int64
#  23  Question_19                                85 non-null     int64
#  24  Question_20                                85 non-null     int64
#  25  Question_21                                85 non-null     int64
#  26  Question_22                                85 non-null     int64
#  27  Question_23                                85 non-null     int64
#  28  Question_24                                85 non-null     int64
#  29  Question_25                                85 non-null     int64
#  30  Question_26                                85 non-null     int64
#  31  Question_27                                85 non-null     int64
#  32  solely_for_your_use?_Imp_1                 85 non-null     int64
# dtypes: int64(33)
# memory usage: 22.6 KB

# %%
log_reg = linear_model

# starting the timer
start = time.time()

log_reg = linear_model.LogisticRegression(max_iter=3000)
log_reg.fit(Xtrain,Ytrain)

end = time.time() - start
print(f"Logistic Regession AFTER DROPPING HIGHLY CORRELATED VARIABLES took {end} seconds")

# Evaluating model on test data
yhat_log_Reg = log_reg.predict(Xtest)

# checking for Recall, Precision and Fscore of Baseline model
p,r,f,s = precision_recall_fscore_support(Ytest,yhat_log_Reg, average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, yhat_log_Reg, average='weighted')
# Out:
# Logistic Regession AFTER DROPPING HIGHLY CORRELATED VARIABLES took 0.9907491207122803 seconds
# Precision:0.5036572204639432
# Recall: 0.5059885916088923
# F-score: 0.4983405483405484
# 0.4602079619726678

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, yhat_log_Reg)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_LR_FS.PNG")

# %%
# create a regressor object
d_tree = DecisionTreeClassifier(random_state = 0) 

# starting the timer
start = time.time()
  
# fit the regressor with X and Y data
d_tree.fit(Xtrain, Ytrain)

# predicting on the test set
y_pred = d_tree.predict(Xtest)

end = time.time() - start
print(f"Decision Tree took {end} seconds")

# checking for Recall, Precision and Fscore of Baseline model
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred, average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred, average='weighted')
# Out:
# Decision Tree took 0.012489557266235352 seconds
# Precision:0.5367572786690433
# Recall: 0.57433193373043
# F-score: 0.5475045880811625
# 0.5223060354775722

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_DT_FS.PNG")

# %%
# create a regressor object
d_tree_ = DecisionTreeClassifier(random_state = 7)

# Specifying the hyperparameters and setting
dt_params = [{'max_depth':[2,4,10,50,100,None]},
             {'random_state':[2,7,42]},
             {'max_features':[9,15,36]}]

# Instantiating the Grid search class (cross-validation)
grid_search = GridSearchCV(d_tree_, dt_params, cv=10, scoring="f1_macro", return_train_score=True)

# Starting the timer
start = time.time()

# Fitting the model
grid_search.fit(Xtrain,Ytrain)

# predicting on the test set
y_pred_tuned = grid_search.predict(Xtest)

end = time.time() - start
print(f"HYPERPARAMETRE TUNED Decision Tree took {end} seconds")

# checking for Recall, Precision and Fscore of Baseline model
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_tuned, average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred_tuned, average='weighted')
# Out:
# HYPERPARAMETRE TUNED Decision Tree took 1.326014518737793 seconds
# Precision:0.6595238095238096
# Recall: 0.6878775672948605
# F-score: 0.6587004177066288
# 0.6553518111574377

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_tuned)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_DT_TUNED_FS.PNG")

# %%
# create a RandomForestClassifier object
forest_reg_ = RandomForestClassifier(n_estimators= 10) 

# starting the timer
start = time.time()
  
# fit the regressor with X and Y data
forest_reg_.fit(Xtrain, Ytrain)

# predicting on the test set
y_pred_RF = forest_reg_.predict(Xtest)

end = time.time() - start
print(f"Radom forest took {end} seconds")

# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_RF,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

scores = cross_val_score(forest_reg_, Xtrain, Ytrain, scoring = "neg_mean_squared_error" , cv=10)
rmse_scores = np.sqrt(-scores)

#print(rmse_scores)

metrics.f1_score(Ytest, y_pred_RF, average='weighted')
# Out:
# Radom forest took 0.028995275497436523 seconds
# Precision:0.6734628237259815
# Recall: 0.5958939556683918
# F-score: 0.6132671250318309
# 0.6214490930061864

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_RF)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_RF_FS.PNG")

# %%
# Initializing the RandomForestClassifier class
forest_reg_tuned = RandomForestClassifier(random_state=7)

# Specifiying the Parameters
param_grid = [{'n_estimators': [10, 20, 100],
               'max_depth': [5,10, None],
               'bootstrap': [True,False]},]

# Cross-validating for the Fscore for all Hyperparameters
rf_grid_search = GridSearchCV(forest_reg_tuned, param_grid , cv=10,
                              scoring='f1_macro',
                              return_train_score=True)

# starting the timer
start = time.time()

# Fitting the Random Forest HyperParameter Tuned model
rf_grid_search.fit(Xtrain, Ytrain)

end = time.time() - start
print(f"Tuned Random Forest AFTER REMOVING HIGHLY CORRELATED FEATURES took {end} seconds")

#finding the best MOdel
rf_grid_search.best_estimator_


# predicting on the test set
y_pred_RF_tuned = rf_grid_search.predict(Xtest)

# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_RF_tuned,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred_RF_tuned, average='weighted')
# Out:
# Tuned Random Forest AFTER REMOVING HIGHLY CORRELATED FEATURES took 21.507746696472168 seconds
# Precision:0.6898738442745519
# Recall: 0.6863119649773786
# F-score: 0.6853832442067737
# 0.6469060351413293

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_RF_tuned)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_RF_TUNED_FS.PNG")

# %%
knn_ = KNeighborsClassifier(n_neighbors=5)

# starting the timer
start = time.time()

knn_.fit(Xtrain, Ytrain)

end = time.time() - start
print(f"KNN WITH SMOTE OVERSAMPLING took {end} seconds")

# Evaluating model on test data
yhat_knn_ = knn_.predict(Xtest)

# checking for Recall, Precision and Fscore of Baseline model
p,r,f,s = precision_recall_fscore_support(Ytest,yhat_knn_, average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, yhat_knn_, average='weighted')
# Out:
# KNN WITH SMOTE OVERSAMPLING took 0.003791332244873047 seconds
# Precision:0.35069124423963133
# Recall: 0.3739173420564398
# F-score: 0.3499498746867168
# 0.35842518059855527

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, yhat_knn_)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_KNN_FS.PNG")

# %%
# Instantiating the SVC class
svm_c_ = SVC()

# starting the timer
start = time.time()

# Fitting the Random Forest HyperParameter Tuned model
svm_c_.fit(Xtrain, Ytrain)

end = time.time() - start
print(f"SVM after smote oversampling took {end} seconds")


# predicting on the test set
y_pred_svm = svm_c_.predict(Xtest)

# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_svm,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred_svm, average='weighted')
# Out:
# SVM after smote oversampling took 0.02184295654296875 seconds
# Precision:0.35693354264782834
# Recall: 0.39097622302509516
# F-score: 0.36795621143447227
# 0.44718316084044984

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_svm)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_SVM_FS.PNG")

# %%
from sklearn.svm import SVC
# Instantiating the SVC class
lsvm = SVC()

#specifying the Hyperparameters
param_grid_lsvm = {'C' : [0.01, 0.1, 1, 3, 10, 100],
                   'max_iter' : [10,50,100,1000,5000,10000],
                   'random_state' : [7,42]
                   }

# Cross-validating for the Fscore for all Hyperparameters
svm_grid_search = GridSearchCV(lsvm, param_grid_lsvm , cv=10,scoring='f1_macro',return_train_score=True)

# starting the timer
start = time.time()

# Fitting the Random Forest HyperParameter Tuned model
svm_grid_search.fit(Xtrain, Ytrain)

end = time.time() - start
print(f"SVM after REMOVING HIGHLY CORRELATED VARIABLES took {end} seconds")

#finding the best MOdel
print(f"Best estimator  = {svm_grid_search.best_estimator_}")

# predicting on the test set
y_pred_svm = svm_grid_search.predict(Xtest)

# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,y_pred_svm,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, y_pred_svm, average='weighted')
# Out:
# SVM after REMOVING HIGHLY CORRELATED VARIABLES took 19.66161870956421 seconds
# Best estimator  = SVC(C=10, max_iter=1000, random_state=7)
# Precision:0.4640351595183528
# Recall: 0.5356093154965336
# F-score: 0.49244663382594417
# 0.47282438994406545

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, y_pred_svm)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_SVM_TUNED_FS.PNG")

# %%
n_class = len(unique(test_set))

# define the keras model
model = Sequential()
model.add(Dense(20, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(10, activation='relu', kernel_initializer='he_normal'))
model.add(Dense(n_class, activation='softmax'))

# compile the keras model
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam')

# fit the keras model on the dataset
model.fit(Xtrain, Ytrain, epochs=200, batch_size=16, verbose=2)
# evaluate on test set
yhat_NN = model.predict(Xtest)
yhat_NN = argmax(yhat_NN, axis=-1).astype('int')
acc = accuracy_score(Ytest, yhat_NN)
print('Accuracy: %.3f' % acc)


# checking for Recall, Precision and Fscore of 
p,r,f,s = precision_recall_fscore_support(Ytest,yhat_NN,average="macro")

# Printing the results
print(f"Precision:{p}")
print(f"Recall: {r}")
print(f"F-score: {f}")

metrics.f1_score(Ytest, yhat_NN, average='weighted')
# Out:
# Epoch 1/200
# 22/22 - 1s - loss: 6.6731 - 718ms/epoch - 33ms/step
# Epoch 2/200
# 22/22 - 0s - loss: 3.6438 - 63ms/epoch - 3ms/step
# Epoch 3/200
# 22/22 - 0s - loss: 2.5617 - 67ms/epoch - 3ms/step
# Epoch 4/200
# 22/22 - 0s - loss: 2.1229 - 69ms/epoch - 3ms/step
# Epoch 5/200
# 22/22 - 0s - loss: 1.9456 - 62ms/epoch - 3ms/step
# Epoch 6/200
# 22/22 - 0s - loss: 1.8245 - 58ms/epoch - 3ms/step
# Epoch 7/200
# 22/22 - 0s - loss: 1.7538 - 66ms/epoch - 3ms/step
# Epoch 8/200
# 22/22 - 0s - loss: 1.6935 - 58ms/epoch - 3ms/step
# Epoch 9/200
# 22/22 - 0s - loss: 1.6398 - 56ms/epoch - 3ms/step
# Epoch 10/200
# 22/22 - 0s - loss: 1.5931 - 57ms/epoch - 3ms/step
# Epoch 11/200
# 22/22 - 0s - loss: 1.5625 - 77ms/epoch - 4ms/step
# Epoch 12/200
# 22/22 - 0s - loss: 1.5212 - 56ms/epoch - 3ms/step
# Epoch 13/200
# 22/22 - 0s - loss: 1.4949 - 62ms/epoch - 3ms/step
# Epoch 14/200
# 22/22 - 0s - loss: 1.4659 - 75ms/epoch - 3ms/step
# Epoch 15/200
# 22/22 - 0s - loss: 1.4385 - 68ms/epoch - 3ms/step
# Epoch 16/200
# 22/22 - 0s - loss: 1.4148 - 65ms/epoch - 3ms/step
# Epoch 17/200
# 22/22 - 0s - loss: 1.3962 - 64ms/epoch - 3ms/step
# Epoch 18/200
# 22/22 - 0s - loss: 1.3771 - 72ms/epoch - 3ms/step
# Epoch 19/200
# 22/22 - 0s - loss: 1.3575 - 62ms/epoch - 3ms/step
# Epoch 20/200
# 22/22 - 0s - loss: 1.3389 - 57ms/epoch - 3ms/step
# Epoch 21/200
# 22/22 - 0s - loss: 1.3307 - 57ms/epoch - 3ms/step
# Epoch 22/200
# 22/22 - 0s - loss: 1.3130 - 55ms/epoch - 2ms/step
# Epoch 23/200
# 22/22 - 0s - loss: 1.3013 - 82ms/epoch - 4ms/step
# Epoch 24/200
# 22/22 - 0s - loss: 1.2826 - 56ms/epoch - 3ms/step
# Epoch 25/200
# 22/22 - 0s - loss: 1.2777 - 72ms/epoch - 3ms/step
# Epoch 26/200
# 22/22 - 0s - loss: 1.2613 - 71ms/epoch - 3ms/step
# Epoch 27/200
# 22/22 - 0s - loss: 1.2534 - 81ms/epoch - 4ms/step
# Epoch 28/200
# 22/22 - 0s - loss: 1.2406 - 66ms/epoch - 3ms/step
# Epoch 29/200
# 22/22 - 0s - loss: 1.2296 - 61ms/epoch - 3ms/step
# Epoch 30/200
# 22/22 - 0s - loss: 1.2225 - 46ms/epoch - 2ms/step
# Epoch 31/200
# 22/22 - 0s - loss: 1.2067 - 54ms/epoch - 2ms/step
# Epoch 32/200
# 22/22 - 0s - loss: 1.2025 - 42ms/epoch - 2ms/step
# Epoch 33/200
# 22/22 - 0s - loss: 1.1854 - 39ms/epoch - 2ms/step
# Epoch 34/200
# 22/22 - 0s - loss: 1.1805 - 41ms/epoch - 2ms/step
# Epoch 35/200
# 22/22 - 0s - loss: 1.1794 - 40ms/epoch - 2ms/step
# Epoch 36/200
# 22/22 - 0s - loss: 1.1802 - 40ms/epoch - 2ms/step
# Epoch 37/200
# 22/22 - 0s - loss: 1.1481 - 42ms/epoch - 2ms/step
# Epoch 38/200
# 22/22 - 0s - loss: 1.1628 - 48ms/epoch - 2ms/step
# Epoch 39/200
# 22/22 - 0s - loss: 1.1413 - 38ms/epoch - 2ms/step
# Epoch 40/200
# 22/22 - 0s - loss: 1.1438 - 39ms/epoch - 2ms/step
# Epoch 41/200
# 22/22 - 0s - loss: 1.1275 - 41ms/epoch - 2ms/step
# Epoch 42/200
# 22/22 - 0s - loss: 1.1243 - 44ms/epoch - 2ms/step
# Epoch 43/200
# 22/22 - 0s - loss: 1.1106 - 46ms/epoch - 2ms/step
# Epoch 44/200
# 22/22 - 0s - loss: 1.1023 - 61ms/epoch - 3ms/step
# Epoch 45/200
# 22/22 - 0s - loss: 1.1033 - 40ms/epoch - 2ms/step
# Epoch 46/200
# 22/22 - 0s - loss: 1.0994 - 37ms/epoch - 2ms/step
# Epoch 47/200
# 22/22 - 0s - loss: 1.0926 - 42ms/epoch - 2ms/step
# Epoch 48/200
# 22/22 - 0s - loss: 1.0824 - 50ms/epoch - 2ms/step
# Epoch 49/200
# 22/22 - 0s - loss: 1.0800 - 41ms/epoch - 2ms/step
# Epoch 50/200
# 22/22 - 0s - loss: 1.0627 - 38ms/epoch - 2ms/step
# Epoch 51/200
# 22/22 - 0s - loss: 1.0610 - 43ms/epoch - 2ms/step
# Epoch 52/200
# 22/22 - 0s - loss: 1.0563 - 48ms/epoch - 2ms/step
# Epoch 53/200
# 22/22 - 0s - loss: 1.0439 - 46ms/epoch - 2ms/step
# Epoch 54/200
# 22/22 - 0s - loss: 1.0391 - 37ms/epoch - 2ms/step
# Epoch 55/200
# 22/22 - 0s - loss: 1.0331 - 43ms/epoch - 2ms/step
# Epoch 56/200
# 22/22 - 0s - loss: 1.0228 - 41ms/epoch - 2ms/step
# Epoch 57/200
# 22/22 - 0s - loss: 1.0189 - 45ms/epoch - 2ms/step
# Epoch 58/200
# 22/22 - 0s - loss: 1.0186 - 38ms/epoch - 2ms/step
# Epoch 59/200
# 22/22 - 0s - loss: 1.0079 - 37ms/epoch - 2ms/step
# Epoch 60/200
# 22/22 - 0s - loss: 1.0001 - 38ms/epoch - 2ms/step
# Epoch 61/200
# 22/22 - 0s - loss: 1.0079 - 36ms/epoch - 2ms/step
# Epoch 62/200
# 22/22 - 0s - loss: 0.9903 - 44ms/epoch - 2ms/step
# Epoch 63/200
# 22/22 - 0s - loss: 0.9961 - 39ms/epoch - 2ms/step
# Epoch 64/200
# 22/22 - 0s - loss: 1.0068 - 40ms/epoch - 2ms/step
# Epoch 65/200
# 22/22 - 0s - loss: 0.9933 - 37ms/epoch - 2ms/step
# Epoch 66/200
# 22/22 - 0s - loss: 0.9724 - 42ms/epoch - 2ms/step
# Epoch 67/200
# 22/22 - 0s - loss: 0.9806 - 56ms/epoch - 3ms/step
# Epoch 68/200
# 22/22 - 0s - loss: 0.9627 - 40ms/epoch - 2ms/step
# Epoch 69/200
# 22/22 - 0s - loss: 0.9795 - 40ms/epoch - 2ms/step
# Epoch 70/200
# 22/22 - 0s - loss: 0.9645 - 43ms/epoch - 2ms/step
# Epoch 71/200
# 22/22 - 0s - loss: 0.9571 - 43ms/epoch - 2ms/step
# Epoch 72/200
# 22/22 - 0s - loss: 0.9670 - 45ms/epoch - 2ms/step
# Epoch 73/200
# 22/22 - 0s - loss: 0.9515 - 39ms/epoch - 2ms/step
# Epoch 74/200
# 22/22 - 0s - loss: 0.9510 - 39ms/epoch - 2ms/step
# Epoch 75/200
# 22/22 - 0s - loss: 0.9473 - 39ms/epoch - 2ms/step
# Epoch 76/200
# 22/22 - 0s - loss: 0.9399 - 41ms/epoch - 2ms/step
# Epoch 77/200
# 22/22 - 0s - loss: 0.9302 - 44ms/epoch - 2ms/step
# Epoch 78/200
# 22/22 - 0s - loss: 0.9223 - 39ms/epoch - 2ms/step
# Epoch 79/200
# 22/22 - 0s - loss: 0.9298 - 39ms/epoch - 2ms/step
# Epoch 80/200
# 22/22 - 0s - loss: 0.9257 - 38ms/epoch - 2ms/step
# Epoch 81/200
# 22/22 - 0s - loss: 0.9214 - 43ms/epoch - 2ms/step
# Epoch 82/200
# 22/22 - 0s - loss: 0.9238 - 51ms/epoch - 2ms/step
# Epoch 83/200
# 22/22 - 0s - loss: 0.9114 - 43ms/epoch - 2ms/step
# Epoch 84/200
# 22/22 - 0s - loss: 0.9197 - 42ms/epoch - 2ms/step
# Epoch 85/200
# 22/22 - 0s - loss: 0.9205 - 42ms/epoch - 2ms/step
# Epoch 86/200
# 22/22 - 0s - loss: 0.8978 - 41ms/epoch - 2ms/step
# Epoch 87/200
# 22/22 - 0s - loss: 0.8962 - 53ms/epoch - 2ms/step
# Epoch 88/200
# 22/22 - 0s - loss: 0.8890 - 41ms/epoch - 2ms/step
# Epoch 89/200
# 22/22 - 0s - loss: 0.8949 - 54ms/epoch - 2ms/step
# Epoch 90/200
# 22/22 - 0s - loss: 0.8833 - 38ms/epoch - 2ms/step
# Epoch 91/200
# 22/22 - 0s - loss: 0.8876 - 54ms/epoch - 2ms/step
# Epoch 92/200
# 22/22 - 0s - loss: 0.8776 - 40ms/epoch - 2ms/step
# Epoch 93/200
# 22/22 - 0s - loss: 0.8705 - 42ms/epoch - 2ms/step
# Epoch 94/200
# 22/22 - 0s - loss: 0.8745 - 39ms/epoch - 2ms/step
# Epoch 95/200
# 22/22 - 0s - loss: 0.8729 - 38ms/epoch - 2ms/step
# Epoch 96/200
# 22/22 - 0s - loss: 0.8650 - 42ms/epoch - 2ms/step
# Epoch 97/200
# 22/22 - 0s - loss: 0.8649 - 40ms/epoch - 2ms/step
# Epoch 98/200
# 22/22 - 0s - loss: 0.8683 - 41ms/epoch - 2ms/step
# Epoch 99/200
# 22/22 - 0s - loss: 0.8526 - 39ms/epoch - 2ms/step
# Epoch 100/200
# 22/22 - 0s - loss: 0.8636 - 38ms/epoch - 2ms/step
# Epoch 101/200
# 22/22 - 0s - loss: 0.8532 - 42ms/epoch - 2ms/step
# Epoch 102/200
# 22/22 - 0s - loss: 0.8388 - 40ms/epoch - 2ms/step
# Epoch 103/200
# 22/22 - 0s - loss: 0.8360 - 39ms/epoch - 2ms/step
# Epoch 104/200
# 22/22 - 0s - loss: 0.8347 - 37ms/epoch - 2ms/step
# Epoch 105/200
# 22/22 - 0s - loss: 0.8389 - 38ms/epoch - 2ms/step
# Epoch 106/200
# 22/22 - 0s - loss: 0.8451 - 37ms/epoch - 2ms/step
# Epoch 107/200
# 22/22 - 0s - loss: 0.8251 - 48ms/epoch - 2ms/step
# Epoch 108/200
# 22/22 - 0s - loss: 0.8319 - 37ms/epoch - 2ms/step
# Epoch 109/200
# 22/22 - 0s - loss: 0.8186 - 40ms/epoch - 2ms/step
# Epoch 110/200
# 22/22 - 0s - loss: 0.8171 - 40ms/epoch - 2ms/step
# Epoch 111/200
# 22/22 - 0s - loss: 0.8317 - 60ms/epoch - 3ms/step
# Epoch 112/200
# 22/22 - 0s - loss: 0.8121 - 42ms/epoch - 2ms/step
# Epoch 113/200
# 22/22 - 0s - loss: 0.8100 - 43ms/epoch - 2ms/step
# Epoch 114/200
# 22/22 - 0s - loss: 0.8176 - 41ms/epoch - 2ms/step
# Epoch 115/200
# 22/22 - 0s - loss: 0.7955 - 46ms/epoch - 2ms/step
# Epoch 116/200
# 22/22 - 0s - loss: 0.7999 - 38ms/epoch - 2ms/step
# Epoch 117/200
# 22/22 - 0s - loss: 0.7966 - 41ms/epoch - 2ms/step
# Epoch 118/200
# 22/22 - 0s - loss: 0.8230 - 38ms/epoch - 2ms/step
# Epoch 119/200
# 22/22 - 0s - loss: 0.7967 - 41ms/epoch - 2ms/step
# Epoch 120/200
# 22/22 - 0s - loss: 0.7919 - 41ms/epoch - 2ms/step
# Epoch 121/200
# 22/22 - 0s - loss: 0.7818 - 44ms/epoch - 2ms/step
# Epoch 122/200
# 22/22 - 0s - loss: 0.7804 - 38ms/epoch - 2ms/step
# Epoch 123/200
# 22/22 - 0s - loss: 0.7780 - 39ms/epoch - 2ms/step
# Epoch 124/200
# 22/22 - 0s - loss: 0.7844 - 39ms/epoch - 2ms/step
# Epoch 125/200
# 22/22 - 0s - loss: 0.7729 - 44ms/epoch - 2ms/step
# Epoch 126/200
# 22/22 - 0s - loss: 0.7780 - 38ms/epoch - 2ms/step
# Epoch 127/200
# 22/22 - 0s - loss: 0.7831 - 40ms/epoch - 2ms/step
# Epoch 128/200
# 22/22 - 0s - loss: 0.7726 - 38ms/epoch - 2ms/step
# Epoch 129/200
# 22/22 - 0s - loss: 0.7588 - 40ms/epoch - 2ms/step
# Epoch 130/200
# 22/22 - 0s - loss: 0.7563 - 49ms/epoch - 2ms/step
# Epoch 131/200
# 22/22 - 0s - loss: 0.7523 - 44ms/epoch - 2ms/step
# Epoch 132/200
# 22/22 - 0s - loss: 0.7519 - 40ms/epoch - 2ms/step
# Epoch 133/200
# 22/22 - 0s - loss: 0.7634 - 45ms/epoch - 2ms/step
# Epoch 134/200
# 22/22 - 0s - loss: 0.7382 - 59ms/epoch - 3ms/step
# Epoch 135/200
# 22/22 - 0s - loss: 0.7483 - 40ms/epoch - 2ms/step
# Epoch 136/200
# 22/22 - 0s - loss: 0.7518 - 45ms/epoch - 2ms/step
# Epoch 137/200
# 22/22 - 0s - loss: 0.7472 - 41ms/epoch - 2ms/step
# Epoch 138/200
# 22/22 - 0s - loss: 0.7368 - 38ms/epoch - 2ms/step
# Epoch 139/200
# 22/22 - 0s - loss: 0.7297 - 48ms/epoch - 2ms/step
# Epoch 140/200
# 22/22 - 0s - loss: 0.7317 - 41ms/epoch - 2ms/step
# Epoch 141/200
# 22/22 - 0s - loss: 0.7391 - 53ms/epoch - 2ms/step
# Epoch 142/200
# 22/22 - 0s - loss: 0.7342 - 48ms/epoch - 2ms/step
# Epoch 143/200
# 22/22 - 0s - loss: 0.7423 - 37ms/epoch - 2ms/step
# Epoch 144/200
# 22/22 - 0s - loss: 0.7343 - 38ms/epoch - 2ms/step
# Epoch 145/200
# 22/22 - 0s - loss: 0.7191 - 36ms/epoch - 2ms/step
# Epoch 146/200
# 22/22 - 0s - loss: 0.7144 - 36ms/epoch - 2ms/step
# Epoch 147/200
# 22/22 - 0s - loss: 0.7088 - 42ms/epoch - 2ms/step
# Epoch 148/200
# 22/22 - 0s - loss: 0.7052 - 44ms/epoch - 2ms/step
# Epoch 149/200
# 22/22 - 0s - loss: 0.7048 - 39ms/epoch - 2ms/step
# Epoch 150/200
# 22/22 - 0s - loss: 0.7018 - 40ms/epoch - 2ms/step
# Epoch 151/200
# 22/22 - 0s - loss: 0.6913 - 39ms/epoch - 2ms/step
# Epoch 152/200
# 22/22 - 0s - loss: 0.7037 - 39ms/epoch - 2ms/step
# Epoch 153/200
# 22/22 - 0s - loss: 0.7067 - 48ms/epoch - 2ms/step
# Epoch 154/200
# 22/22 - 0s - loss: 0.7006 - 38ms/epoch - 2ms/step
# Epoch 155/200
# 22/22 - 0s - loss: 0.6865 - 44ms/epoch - 2ms/step
# Epoch 156/200
# 22/22 - 0s - loss: 0.6771 - 48ms/epoch - 2ms/step
# Epoch 157/200
# 22/22 - 0s - loss: 0.6815 - 43ms/epoch - 2ms/step
# Epoch 158/200
# 22/22 - 0s - loss: 0.6796 - 38ms/epoch - 2ms/step
# Epoch 159/200
# 22/22 - 0s - loss: 0.6880 - 39ms/epoch - 2ms/step
# Epoch 160/200
# 22/22 - 0s - loss: 0.6780 - 39ms/epoch - 2ms/step
# Epoch 161/200
# 22/22 - 0s - loss: 0.6871 - 38ms/epoch - 2ms/step
# Epoch 162/200
# 22/22 - 0s - loss: 0.6657 - 40ms/epoch - 2ms/step
# Epoch 163/200
# 22/22 - 0s - loss: 0.6685 - 42ms/epoch - 2ms/step
# Epoch 164/200
# 22/22 - 0s - loss: 0.6691 - 38ms/epoch - 2ms/step
# Epoch 165/200
# 22/22 - 0s - loss: 0.6663 - 37ms/epoch - 2ms/step
# Epoch 166/200
# 22/22 - 0s - loss: 0.6639 - 38ms/epoch - 2ms/step
# Epoch 167/200
# 22/22 - 0s - loss: 0.6613 - 40ms/epoch - 2ms/step
# Epoch 168/200
# 22/22 - 0s - loss: 0.6537 - 46ms/epoch - 2ms/step
# Epoch 169/200
# 22/22 - 0s - loss: 0.6463 - 42ms/epoch - 2ms/step
# Epoch 170/200
# 22/22 - 0s - loss: 0.6412 - 37ms/epoch - 2ms/step
# Epoch 171/200
# 22/22 - 0s - loss: 0.6476 - 41ms/epoch - 2ms/step
# Epoch 172/200
# 22/22 - 0s - loss: 0.6520 - 45ms/epoch - 2ms/step
# Epoch 173/200
# 22/22 - 0s - loss: 0.6509 - 40ms/epoch - 2ms/step
# Epoch 174/200
# 22/22 - 0s - loss: 0.6432 - 38ms/epoch - 2ms/step
# Epoch 175/200
# 22/22 - 0s - loss: 0.6236 - 41ms/epoch - 2ms/step
# Epoch 176/200
# 22/22 - 0s - loss: 0.6407 - 37ms/epoch - 2ms/step
# Epoch 177/200
# 22/22 - 0s - loss: 0.6327 - 43ms/epoch - 2ms/step
# Epoch 178/200
# 22/22 - 0s - loss: 0.6360 - 40ms/epoch - 2ms/step
# Epoch 179/200
# 22/22 - 0s - loss: 0.6242 - 49ms/epoch - 2ms/step
# Epoch 180/200
# 22/22 - 0s - loss: 0.6192 - 38ms/epoch - 2ms/step
# Epoch 181/200
# 22/22 - 0s - loss: 0.6174 - 49ms/epoch - 2ms/step
# Epoch 182/200
# 22/22 - 0s - loss: 0.6196 - 37ms/epoch - 2ms/step
# Epoch 183/200
# 22/22 - 0s - loss: 0.6200 - 39ms/epoch - 2ms/step
# Epoch 184/200
# 22/22 - 0s - loss: 0.6098 - 37ms/epoch - 2ms/step
# Epoch 185/200
# 22/22 - 0s - loss: 0.6166 - 40ms/epoch - 2ms/step
# Epoch 186/200
# 22/22 - 0s - loss: 0.6059 - 44ms/epoch - 2ms/step
# Epoch 187/200
# 22/22 - 0s - loss: 0.6062 - 41ms/epoch - 2ms/step
# Epoch 188/200
# 22/22 - 0s - loss: 0.6025 - 38ms/epoch - 2ms/step
# Epoch 189/200
# 22/22 - 0s - loss: 0.6062 - 37ms/epoch - 2ms/step
# Epoch 190/200
# 22/22 - 0s - loss: 0.6043 - 44ms/epoch - 2ms/step
# Epoch 191/200
# 22/22 - 0s - loss: 0.6068 - 38ms/epoch - 2ms/step
# Epoch 192/200
# 22/22 - 0s - loss: 0.6058 - 43ms/epoch - 2ms/step
# Epoch 193/200
# 22/22 - 0s - loss: 0.6159 - 42ms/epoch - 2ms/step
# Epoch 194/200
# 22/22 - 0s - loss: 0.6076 - 41ms/epoch - 2ms/step
# Epoch 195/200
# 22/22 - 0s - loss: 0.5920 - 46ms/epoch - 2ms/step
# Epoch 196/200
# 22/22 - 0s - loss: 0.6048 - 38ms/epoch - 2ms/step
# Epoch 197/200
# 22/22 - 0s - loss: 0.6335 - 41ms/epoch - 2ms/step
# Epoch 198/200
# 22/22 - 0s - loss: 0.5824 - 40ms/epoch - 2ms/step
# Epoch 199/200
# 22/22 - 0s - loss: 0.5865 - 41ms/epoch - 2ms/step
# Epoch 200/200
# 22/22 - 0s - loss: 0.5772 - 48ms/epoch - 2ms/step
# 3/3 [==============================] - 0s 5ms/step
# Accuracy: 0.447
# Precision:0.4653846153846154
# Recall: 0.5203727663314129
# F-score: 0.4691759510652585
# 0.44824953513654153

# %%
# cross-validation confusion matrix data
cm = confusion_matrix(Ytest, yhat_NN)
cm_df = pd.DataFrame(cm, index = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'],
                     columns = ['Strongly agree','Agree','Somewhat agree','Neutral','Somewhat disagree','Disagree','Strongly disagree'])
#Plotting the confusion matrix
plt.figure(figsize=(6,5))
sns.heatmap(cm_df,fmt=".1f", annot=True, linewidths=.5,cmap='coolwarm')
plt.title('Confusion Matrix')
plt.ylabel('Actal Values')
plt.xlabel('Predicted Values')
plt.show()
plt.savefig("CF_NN_FS.PNG")

# %%
from sklearn import model_selection

# prepare models
models = []
models.append(('Logistic Regression', LogisticRegression()))
models.append(('Decision Tree', DecisionTreeClassifier()))
models.append(('Decision Tree tuned', DecisionTreeClassifier()))
models.append(('Random Forest', RandomForestClassifier()))
models.append(('Random Forest Tuned', RandomForestClassifier()))
models.append(('SVM', SVC()))
models.append(('Neural Netwrok', SVC()))
# evaluate each model in turn
results = []
names = []
scoring = 'accuracy'
for name, model in models:
 kfold = model_selection.KFold(n_splits=10, random_state=7, shuffle=True)
 cv_results = model_selection.cross_val_score(model, Xtrain, Ytrain, cv=kfold, scoring=scoring)
 results.append(cv_results)
 names.append(name)
 msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
 print(msg)
# boxplot algorithm comparison
fig = plt.figure()
fig.suptitle('Algorithm Comparison')
ax = fig.add_subplot(111)
plt.boxplot(results)
ax.set_xticklabels(names)
plt.show()
# Out:
# Logistic Regression: 0.420588 (0.039569)
# Decision Tree: 0.491176 (0.102773)
# Decision Tree tuned: 0.482353 (0.060563)
# Random Forest: 0.523529 (0.062806)
# Random Forest Tuned: 0.532353 (0.060919)
# SVM: 0.447059 (0.039019)
# Neural Netwrok: 0.447059 (0.039019)
